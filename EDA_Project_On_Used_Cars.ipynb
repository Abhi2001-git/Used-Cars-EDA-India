# %% [markdown]
# <a href="https://colab.research.google.com/github/Abhi2001-git/Used-Cars-EDA-India/blob/main/EDA_Project_On_Used_Cars.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# * In FY23, the pre-owned cars sales in India stood at about 51 lakh units. The domestic used car industry was valued at USD 32.44 billion in FY23, as per IBB report by 'car&bike' and 'Das WeltAuto by Volkswagen'.
# * India's pre-owned cars sales market is expected to reach 1.09 crore units with value more than doubling to USD 73 billion by FY28, according to the latest Indian Blue Book (IBB) report.
# * This exploratory data analysis (EDA) aims to understand the relationships between variables, discover crucial factors, and identify patterns that will help both buyers and sellers to make data-driven decisions.

# %% [markdown]
# ## IMPORTING LIRBARIES

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd, numpy as np
import re
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## WEB SCRAPPING DATA FROM CARS24.COM WEBSITE

# %% [markdown]
# In this exploratory data analysis (EDA), we examined the top 9 cities in India—New Delhi, Mumbai, Bangalore, Hyderabad, Ahmedabad, Chennai, Kolkata, Surat, and Pune—and the top 5 most sold car brands: Maruti, Hyundai, Honda, Tata, and Mahindra.

# %%
city = ["new-delhi","mumbai","bangalore","hyderabad","ahmedabad","chennai","kolkata","surat","pune"]

# %%
brands = ["maruti","hyundai","honda","tata","mahindra"]

# %% [markdown]
# ### new-delhi

# %% [markdown]
# ##### maruti

# %%
url = "https://www.cars24.com/buy-used-maruti-cars-new-delhi/"
req = requests.get(url)
soup = BeautifulSoup(req.text)


model_year = []
brand = []
model = []
transmission = []
distance = []
ownership = []
fuel = []
downpayment = []
price = []

for i in soup.find_all("h3",class_="_2lmIw"):
  text = i.text
  regex1 = re.findall(("(\d+)\s"),text)
  regex2 = re.findall("Maruti",text)
  if regex1:
    model_year.append(regex1[0])
  else:
    model_year.append(np.nan)
  if regex2:
    brand.append(regex2[0])
  else:
    brand.append(np.nan)
  model.append(text[12:])

for i in soup.find_all("ul",class_="_1hOnS"):
  text = i.text
  regex = re.findall("Manual|Automatic",text)
  if regex:
    transmission.append(regex[0])
  else:
    transmission.append(np.nan)

for i in soup.find_all("ul",class_ = "_13yb6"):
  text = i.text
  regex = re.findall("\d+,\d+,\d+|\d+,\d+",text)
  regex2 = re.findall("km(\d+)",text)
  regex3 = re.findall("Petrol|Diesel|CNG|LPG",text)
  if regex:
    distance.append(regex[0])
  else:
    distance.append(np.nan)
  if regex2:
    ownership.append(regex2[0])
  else:
    ownership.append(np.nan)
  if regex3:
    fuel.append(regex3[0])
  else:
    fuel.append(np.nan)

for i in soup.find_all("div",class_ = "_18ToE"):
  text = i.text
  regex = re.findall("^₹(\d+,\d+,\d+)",text)
  if regex:
    price.append(regex[0])
  else:
    price.append(np.nan)

for i in soup.find_all("span",class_ = "_2JX5N"):
  text = i.text
  regex = re.findall("₹(\d+,\d+,\d+|\d+,\d+)",text)
  if regex:
    downpayment.append(regex[0])
  else:
    downpayment.append(np.nan)

# %% [markdown]
# ##### hyundai

# %%
url = "https://www.cars24.com/buy-used-hyundai-cars-new-delhi/"
req = requests.get(url)
soup = BeautifulSoup(req.text)


for i in soup.find_all("h3",class_="_2lmIw"):
  text = i.text
  regex1 = re.findall(("(\d+)\s"),text)
  regex2 = re.findall("Hyundai",text)
  if regex1:
    model_year.append(regex1[0])
  else:
    model_year.append(np.nan)
  if regex2:
    brand.append(regex2[0])
  else:
    brand.append(np.nan)
  model.append(text[13:])

for i in soup.find_all("ul",class_="_1hOnS"):
  text = i.text
  regex = re.findall("Manual|Automatic",text)
  if regex:
    transmission.append(regex[0])
  else:
    transmission.append(np.nan)

for i in soup.find_all("ul",class_ = "_13yb6"):
  text = i.text
  regex = re.findall("\d+,\d+,\d+|\d+,\d+",text)
  regex2 = re.findall("km(\d+)",text)
  regex3 = re.findall("Petrol|Diesel|CNG|LPG",text)
  if regex:
    distance.append(regex[0])
  else:
    distance.append(np.nan)
  if regex2:
    ownership.append(regex2[0])
  else:
    ownership.append(np.nan)
  if regex3:
    fuel.append(regex3[0])
  else:
    fuel.append(np.nan)

for i in soup.find_all("div",class_ = "_18ToE"):
  text = i.text
  regex = re.findall("^₹(\d+,\d+,\d+)",text)
  if regex:
    price.append(regex[0])
  else:
    price.append(np.nan)

for i in soup.find_all("span",class_ = "_2JX5N"):
  text = i.text
  regex = re.findall("₹(\d+,\d+,\d+|\d+,\d+)",text)
  if regex:
    downpayment.append(regex[0])
  else:
    downpayment.append(np.nan)

# %% [markdown]
# ##### honda

# %%
url = "https://www.cars24.com/buy-used-honda-cars-new-delhi/"
req = requests.get(url)
soup = BeautifulSoup(req.text)


for i in soup.find_all("h3",class_="_2lmIw"):
  text = i.text
  regex1 = re.findall(("(\d+)\s"),text)
  regex2 = re.findall("Honda",text)
  if regex1:
    model_year.append(regex1[0])
  else:
    model_year.append(np.nan)
  if regex2:
    brand.append(regex2[0])
  else:
    brand.append(np.nan)
  model.append(text[11:])

for i in soup.find_all("ul",class_="_1hOnS"):
  text = i.text
  regex = re.findall("Manual|Automatic",text)
  if regex:
    transmission.append(regex[0])
  else:
    transmission.append(np.nan)

for i in soup.find_all("ul",class_ = "_13yb6"):
  text = i.text
  regex = re.findall("\d+,\d+,\d+|\d+,\d+",text)
  regex2 = re.findall("km(\d+)",text)
  regex3 = re.findall("Petrol|Diesel|CNG|LPG",text)
  if regex:
    distance.append(regex[0])
  else:
    distance.append(np.nan)
  if regex2:
    ownership.append(regex2[0])
  else:
    ownership.append(np.nan)
  if regex3:
    fuel.append(regex3[0])
  else:
    fuel.append(np.nan)

for i in soup.find_all("div",class_ = "_18ToE"):
  text = i.text
  regex = re.findall("^₹(\d+,\d+,\d+)",text)
  if regex:
    price.append(regex[0])
  else:
    price.append(np.nan)

for i in soup.find_all("span",class_ = "_2JX5N"):
  text = i.text
  regex = re.findall("₹(\d+,\d+,\d+|\d+,\d+)",text)
  if regex:
    downpayment.append(regex[0])
  else:
    downpayment.append(np.nan)

# %% [markdown]
# ##### tata

# %%
url = "https://www.cars24.com/buy-used-tata-cars-new-delhi/"
req = requests.get(url)
soup = BeautifulSoup(req.text)


for i in soup.find_all("h3",class_="_2lmIw"):
  text = i.text
  regex1 = re.findall(("(\d+)\s"),text)
  regex2 = re.findall("Tata",text)
  if regex1:
    model_year.append(regex1[0])
  else:
    model_year.append(np.nan)
  if regex2:
    brand.append(regex2[0])
  else:
    brand.append(np.nan)
  model.append(text[10:])

for i in soup.find_all("ul",class_="_1hOnS"):
  text = i.text
  regex = re.findall("Manual|Automatic",text)
  if regex:
    transmission.append(regex[0])
  else:
    transmission.append(np.nan)

for i in soup.find_all("ul",class_ = "_13yb6"):
  text = i.text
  regex = re.findall("\d+,\d+,\d+|\d+,\d+",text)
  regex2 = re.findall("km(\d+)",text)
  regex3 = re.findall("Petrol|Diesel|CNG|LPG",text)
  if regex:
    distance.append(regex[0])
  else:
    distance.append(np.nan)
  if regex2:
    ownership.append(regex2[0])
  else:
    ownership.append(np.nan)
  if regex3:
    fuel.append(regex3[0])
  else:
    fuel.append(np.nan)

for i in soup.find_all("div",class_ = "_18ToE"):
  text = i.text
  regex = re.findall("^₹(\d+,\d+,\d+)",text)
  if regex:
    price.append(regex[0])
  else:
    price.append(np.nan)

for i in soup.find_all("span",class_ = "_2JX5N"):
  text = i.text
  regex = re.findall("₹(\d+,\d+,\d+|\d+,\d+)",text)
  if regex:
    downpayment.append(regex[0])
  else:
    downpayment.append(np.nan)

# %% [markdown]
# ##### Mahindra

# %%
url = "https://www.cars24.com/buy-used-mahindra-cars-new-delhi/"
req = requests.get(url)
soup = BeautifulSoup(req.text)


for i in soup.find_all("h3",class_="_2lmIw"):
  text = i.text
  regex1 = re.findall(("(\d+)\s"),text)
  regex2 = re.findall("Mahindra",text)
  if regex1:
    model_year.append(regex1[0])
  else:
    model_year.append(np.nan)
  if regex2:
    brand.append(regex2[0])
  else:
    brand.append(np.nan)
  model.append(text[14:])

for i in soup.find_all("ul",class_="_1hOnS"):
  text = i.text
  regex = re.findall("Manual|Automatic",text)
  if regex:
    transmission.append(regex[0])
  else:
    transmission.append(np.nan)

for i in soup.find_all("ul",class_ = "_13yb6"):
  text = i.text
  regex = re.findall("\d+,\d+,\d+|\d+,\d+",text)
  regex2 = re.findall("km(\d+)",text)
  regex3 = re.findall("Petrol|Diesel|CNG|LPG",text)
  if regex:
    distance.append(regex[0])
  else:
    distance.append(np.nan)
  if regex2:
    ownership.append(regex2[0])
  else:
    ownership.append(np.nan)
  if regex3:
    fuel.append(regex3[0])
  else:
    fuel.append(np.nan)

for i in soup.find_all("div",class_ = "_18ToE"):
  text = i.text
  regex = re.findall("^₹(\d+,\d+,\d+)",text)
  if regex:
    price.append(regex[0])
  else:
    price.append(np.nan)

for i in soup.find_all("span",class_ = "_2JX5N"):
  text = i.text
  regex = re.findall("₹(\d+,\d+,\d+|\d+,\d+)",text)
  if regex:
    downpayment.append(regex[0])
  else:
    downpayment.append(np.nan)

# %% [markdown]
# ##### location

# %%
url = "https://www.cars24.com/buy-used-maruti-cars-new-delhi/"
req = requests.get(url)
soup = BeautifulSoup(req.text)

for i in soup.find_all("div",class_ ="_1Bq4a"):
  text = i.text

  regex = re.findall("New Delhi",text)
  print(regex)
# Out:
# ['New Delhi']

# %%
Location = []
size1 = len(brand)
for j in range(0,len(brand)):
  Location.append(regex[0])

# %%
len(Location)
# Out:
# 82

# %% [markdown]
# ### mumbai

# %% [markdown]
# ##### maruti

# %%
url = "https://www.cars24.com/buy-used-maruti-cars-mumbai/"
req = requests.get(url)
soup = BeautifulSoup(req.text)

for i in soup.find_all("h3",class_="_2lmIw"):
  text = i.text
  regex1 = re.findall(("(\d+)\s"),text)
  regex2 = re.findall("Maruti",text)
  if regex1:
    model_year.append(regex1[0])
  else:
    model_year.append(np.nan)
  if regex2:
    brand.append(regex2[0])
  else:
    brand.append(np.nan)
  model.append(text[12:])

for i in soup.find_all("ul",class_="_1hOnS"):
  text = i.text
  regex = re.findall("Manual|Automatic",text)
  if regex:
    transmission.append(regex[0])
  else:
    transmission.append(np.nan)

for i in soup.find_all("ul",class_ = "_13yb6"):
  text = i.text
  regex = re.findall("\d+,\d+,\d+|\d+,\d+",text)
  regex2 = re.findall("km(\d+)",text)
  regex3 = re.findall("Petrol|Diesel|CNG|LPG",text)
  if regex:
    distance.append(regex[0])
  else:
    distance.append(np.nan)
  if regex2:
    ownership.append(regex2[0])
  else:
    ownership.append(np.nan)
  if regex3:
    fuel.append(regex3[0])
  else:
    fuel.append(np.nan)

for i in soup.find_all("div",class_ = "_18ToE"):
  text = i.text
  regex = re.findall("^₹(\d+,\d+,\d+)",text)
  if regex:
    price.append(regex[0])
  else:
    price.append(np.nan)

for i in soup.find_all("span",class_ = "_2JX5N"):
  text = i.text
  regex = re.findall("₹(\d+,\d+,\d+|\d+,\d+)",text)
  if regex:
    downpayment.append(regex[0])
  else:
    downpayment.append(np.nan)

# %% [markdown]
# ##### hyundai

# %%
url = "https://www.cars24.com/buy-used-hyundai-cars-mumbai/"
req = requests.get(url)
soup = BeautifulSoup(req.text)


for i in soup.find_all("h3",class_="_2lmIw"):
  text = i.text
  regex1 = re.findall(("(\d+)\s"),text)
  regex2 = re.findall("Hyundai",text)
  if regex1:
    model_year.append(regex1[0])
  else:
    model_year.append(np.nan)
  if regex2:
    brand.append(regex2[0])
  else:
    brand.append(np.nan)
  model.append(text[13:])

for i in soup.find_all("ul",class_="_1hOnS"):
  text = i.text
  regex = re.findall("Manual|Automatic",text)
  if regex:
    transmission.append(regex[0])
  else:
    transmission.append(np.nan)

for i in soup.find_all("ul",class_ = "_13yb6"):
  text = i.text
  regex = re.findall("\d+,\d+,\d+|\d+,\d+",text)
  regex2 = re.findall("km(\d+)",text)
  regex3 = re.findall("Petrol|Diesel|CNG|LPG",text)
  if regex:
    distance.append(regex[0])
  else:
    distance.append(np.nan)
  if regex2:
    ownership.append(regex2[0])
  else:
    ownership.append(np.nan)
  if regex3:
    fuel.append(regex3[0])
  else:
    fuel.append(np.nan)

for i in soup.find_all("div",class_ = "_18ToE"):
  text = i.text
  regex = re.findall("^₹(\d+,\d+,\d+)",text)
  if regex:
    price.append(regex[0])
  else:
    price.append(np.nan)

for i in soup.find_all("span",class_ = "_2JX5N"):
  text = i.text
  regex = re.findall("₹(\d+,\d+,\d+|\d+,\d+)",text)
  if regex:
    downpayment.append(regex[0])
  else:
    downpayment.append(np.nan)

# %% [markdown]
# ##### honda

# %%
url = "https://www.cars24.com/buy-used-honda-cars-mumbai/"
req = requests.get(url)
soup = BeautifulSoup(req.text)


for i in soup.find_all("h3",class_="_2lmIw"):
  text = i.text
  regex1 = re.findall(("(\d+)\s"),text)
  regex2 = re.findall("Honda",text)
  if regex1:
    model_year.append(regex1[0])
  else:
    model_year.append(np.nan)
  if regex2:
    brand.append(regex2[0])
  else:
    brand.append(np.nan)
  model.append(text[11:])

for i in soup.find_all("ul",class_="_1hOnS"):
  text = i.text
  regex = re.findall("Manual|Automatic",text)
  if regex:
    transmission.append(regex[0])
  else:
    transmission.append(np.nan)

for i in soup.find_all("ul",class_ = "_13yb6"):
  text = i.text
  regex = re.findall("\d+,\d+,\d+|\d+,\d+",text)
  regex2 = re.findall("km(\d+)",text)
  regex3 = re.findall("Petrol|Diesel|CNG|LPG",text)
  if regex:
    distance.append(regex[0])
  else:
    distance.append(np.nan)
  if regex2:
    ownership.append(regex2[0])
  else:
    ownership.append(np.nan)
  if regex3:
    fuel.append(regex3[0])
  else:
    fuel.append(np.nan)

for i in soup.find_all("div",class_ = "_18ToE"):
  text = i.text
  regex = re.findall("^₹(\d+,\d+,\d+)",text)
  if regex:
    price.append(regex[0])
  else:
    price.append(np.nan)

for i in soup.find_all("span",class_ = "_2JX5N"):
  text = i.text
  regex = re.findall("₹(\d+,\d+,\d+|\d+,\d+)",text)
  if regex:
    downpayment.append(regex[0])
  else:
    downpayment.append(np.nan)

# %% [markdown]
# ##### tata

# %%
url = "https://www.cars24.com/buy-used-tata-cars-mumbai/"
req = requests.get(url)
soup = BeautifulSoup(req.text)


for i in soup.find_all("h3",class_="_2lmIw"):
  text = i.text
  regex1 = re.findall(("(\d+)\s"),text)
  regex2 = re.findall("Tata",text)
  if regex1:
    model_year.append(regex1[0])
  else:
    model_year.append(np.nan)
  if regex2:
    brand.append(regex2[0])
  else:
    brand.append(np.nan)
  model.append(text[10:])

for i in soup.find_all("ul",class_="_1hOnS"):
  text = i.text
  regex = re.findall("Manual|Automatic",text)
  if regex:
    transmission.append(regex[0])
  else:
    transmission.append(np.nan)

for i in soup.find_all("ul",class_ = "_13yb6"):
  text = i.text
  regex = re.findall("\d+,\d+,\d+|\d+,\d+",text)
  regex2 = re.findall("km(\d+)",text)
  regex3 = re.findall("Petrol|Diesel|CNG|LPG",text)
  if regex:
    distance.append(regex[0])
  else:
    distance.append(np.nan)
  if regex2:
    ownership.append(regex2[0])
  else:
    ownership.append(np.nan)
  if regex3:
    fuel.append(regex3[0])
  else:
    fuel.append(np.nan)

for i in soup.find_all("div",class_ = "_18ToE"):
  text = i.text
  regex = re.findall("^₹(\d+,\d+,\d+)",text)
  if regex:
    price.append(regex[0])
  else:
    price.append(np.nan)

for i in soup.find_all("span",class_ = "_2JX5N"):
  text = i.text
  regex = re.findall("₹(\d+,\d+,\d+|\d+,\d+)",text)
  if regex:
    downpayment.append(regex[0])
  else:
    downpayment.append(np.nan)

# %% [markdown]
# ##### mahindra

# %%
url = "https://www.cars24.com/buy-used-mahindra-cars-mumbai/"
req = requests.get(url)
soup = BeautifulSoup(req.text)


for i in soup.find_all("h3",class_="_2lmIw"):
  text = i.text
  regex1 = re.findall(("(\d+)\s"),text)
  regex2 = re.findall("Mahindra",text)
  if regex1:
    model_year.append(regex1[0])
  else:
    model_year.append(np.nan)
  if regex2:
    brand.append(regex2[0])
  else:
    brand.append(np.nan)
  model.append(text[14:])

for i in soup.find_all("ul",class_="_1hOnS"):
  text = i.text
  regex = re.findall("Manual|Automatic",text)
  if regex:
    transmission.append(regex[0])
  else:
    transmission.append(np.nan)

for i in soup.find_all("ul",class_ = "_13yb6"):
  text = i.text
  regex = re.findall("\d+,\d+,\d+|\d+,\d+",text)
  regex2 = re.findall("km(\d+)",text)
  regex3 = re.findall("Petrol|Diesel|CNG|LPG",text)
  if regex:
    distance.append(regex[0])
  else:
    distance.append(np.nan)
  if regex2:
    ownership.append(regex2[0])
  else:
    ownership.append(np.nan)
  if regex3:
    fuel.append(regex3[0])
  else:
    fuel.append(np.nan)

for i in soup.find_all("div",class_ = "_18ToE"):
  text = i.text
  regex = re.findall("^₹(\d+,\d+,\d+)",text)
  if regex:
    price.append(regex[0])
  else:
    price.append(np.nan)

for i in soup.find_all("span",class_ = "_2JX5N"):
  text = i.text
  regex = re.findall("₹(\d+,\d+,\d+|\d+,\d+)",text)
  if regex:
    downpayment.append(regex[0])
  else:
    downpayment.append(np.nan)

# %% [markdown]
# ##### location

# %%
url = "https://www.cars24.com/buy-used-maruti-cars-mumbai/"
req = requests.get(url)
soup = BeautifulSoup(req.text)

for i in soup.find_all("div",class_ ="_1Bq4a"):
  text = i.text

  regex = re.findall("Mumbai",text)
  print(regex)
# Out:
# ['Mumbai']

# %%
size2 = len(brand)-size1
for j in range(0,size2):
  Location.append(regex[0])

# %% [markdown]
# ### bangalore

# %% [markdown]
# ##### maruti

# %%
url = "https://www.cars24.com/buy-used-maruti-cars-bangalore/"
req = requests.get(url)
soup = BeautifulSoup(req.text)

for i in soup.find_all("h3",class_="_2lmIw"):
  text = i.text
  regex1 = re.findall(("(\d+)\s"),text)
  regex2 = re.findall("Maruti",text)
  if regex1:
    model_year.append(regex1[0])
  else:
    model_year.append(np.nan)
  if regex2:
    brand.append(regex2[0])
  else:
    brand.append(np.nan)
  model.append(text[12:])

for i in soup.find_all("ul",class_="_1hOnS"):
  text = i.text
  regex = re.findall("Manual|Automatic",text)
  if regex:
    transmission.append(regex[0])
  else:
    transmission.append(np.nan)

for i in soup.find_all("ul",class_ = "_13yb6"):
  text = i.text
  regex = re.findall("\d+,\d+,\d+|\d+,\d+",text)
  regex2 = re.findall("km(\d+)",text)
  regex3 = re.findall("Petrol|Diesel|CNG|LPG",text)
  if regex:
    distance.append(regex[0])
  else:
    distance.append(np.nan)
  if regex2:
    ownership.append(regex2[0])
  else:
    ownership.append(np.nan)
  if regex3:
    fuel.append(regex3[0])
  else:
    fuel.append(np.nan)

for i in soup.find_all("div",class_ = "_18ToE"):
  text = i.text
  regex = re.findall("^₹(\d+,\d+,\d+)",text)
  if regex:
    price.append(regex[0])
  else:
    price.append(np.nan)

for i in soup.find_all("span",class_ = "_2JX5N"):
  text = i.text
  regex = re.findall("₹(\d+,\d+,\d+|\d+,\d+)",text)
  if regex:
    downpayment.append(regex[0])
  else:
    downpayment.append(np.nan)

# %% [markdown]
# ##### hyundai

# %%
url = "https://www.cars24.com/buy-used-hyundai-cars-bangalore/"
req = requests.get(url)
soup = BeautifulSoup(req.text)


for i in soup.find_all("h3",class_="_2lmIw"):
  text = i.text
  regex1 = re.findall(("(\d+)\s"),text)
  regex2 = re.findall("Hyundai",text)
  if regex1:
    model_year.append(regex1[0])
  else:
    model_year.append(np.nan)
  if regex2:
    brand.append(regex2[0])
  else:
    brand.append(np.nan)
  model.append(text[13:])

for i in soup.find_all("ul",class_="_1hOnS"):
  text = i.text
  regex = re.findall("Manual|Automatic",text)
  if regex:
    transmission.append(regex[0])
  else:
    transmission.append(np.nan)

for i in soup.find_all("ul",class_ = "_13yb6"):
  text = i.text
  regex = re.findall("\d+,\d+,\d+|\d+,\d+",text)
  regex2 = re.findall("km(\d+)",text)
  regex3 = re.findall("Petrol|Diesel|CNG|LPG",text)
  if regex:
    distance.append(regex[0])
  else:
    distance.append(np.nan)
  if regex2:
    ownership.append(regex2[0])
  else:
    ownership.append(np.nan)
  if regex3:
    fuel.append(regex3[0])
  else:
    fuel.append(np.nan)

for i in soup.find_all("div",class_ = "_18ToE"):
  text = i.text
  regex = re.findall("^₹(\d+,\d+,\d+)",text)
  if regex:
    price.append(regex[0])
  else:
    price.append(np.nan)

for i in soup.find_all("span",class_ = "_2JX5N"):
  text = i.text
  regex = re.findall("₹(\d+,\d+,\d+|\d+,\d+)",text)
  if regex:
    downpayment.append(regex[0])
  else:
    downpayment.append(np.nan)

# %% [markdown]
# ##### honda

# %%
url = "https://www.cars24.com/buy-used-honda-cars-bangalore/"
req = requests.get(url)
soup = BeautifulSoup(req.text)


for i in soup.find_all("h3",class_="_2lmIw"):
  text = i.text
  regex1 = re.findall(("(\d+)\s"),text)
  regex2 = re.findall("Honda",text)
  if regex1:
    model_year.append(regex1[0])
  else:
    model_year.append(np.nan)
  if regex2:
    brand.append(regex2[0])
  else:
    brand.append(np.nan)
  model.append(text[11:])

for i in soup.find_all("ul",class_="_1hOnS"):
  text = i.text
  regex = re.findall("Manual|Automatic",text)
  if regex:
    transmission.append(regex[0])
  else:
    transmission.append(np.nan)

for i in soup.find_all("ul",class_ = "_13yb6"):
  text = i.text
  regex = re.findall("\d+,\d+,\d+|\d+,\d+",text)
  regex2 = re.findall("km(\d+)",text)
  regex3 = re.findall("Petrol|Diesel|CNG|LPG",text)
  if regex:
    distance.append(regex[0])
  else:
    distance.append(np.nan)
  if regex2:
    ownership.append(regex2[0])
  else:
    ownership.append(np.nan)
  if regex3:
    fuel.append(regex3[0])
  else:
    fuel.append(np.nan)

for i in soup.find_all("div",class_ = "_18ToE"):
  text = i.text
  regex = re.findall("^₹(\d+,\d+,\d+)",text)
  if regex:
    price.append(regex[0])
  else:
    price.append(np.nan)

for i in soup.find_all("span",class_ = "_2JX5N"):
  text = i.text
  regex = re.findall("₹(\d+,\d+,\d+|\d+,\d+)",text)
  if regex:
    downpayment.append(regex[0])
  else:
    downpayment.append(np.nan)

# %% [markdown]
# ##### tata

# %%
url = "https://www.cars24.com/buy-used-tata-cars-bangalore/"
req = requests.get(url)
soup = BeautifulSoup(req.text)


for i in soup.find_all("h3",class_="_2lmIw"):
  text = i.text
  regex1 = re.findall(("(\d+)\s"),text)
  regex2 = re.findall("Tata",text)
  if regex1:
    model_year.append(regex1[0])
  else:
    model_year.append(np.nan)
  if regex2:
    brand.append(regex2[0])
  else:
    brand.append(np.nan)
  model.append(text[10:])

for i in soup.find_all("ul",class_="_1hOnS"):
  text = i.text
  regex = re.findall("Manual|Automatic",text)
  if regex:
    transmission.append(regex[0])
  else:
    transmission.append(np.nan)

for i in soup.find_all("ul",class_ = "_13yb6"):
  text = i.text
  regex = re.findall("\d+,\d+,\d+|\d+,\d+",text)
  regex2 = re.findall("km(\d+)",text)
  regex3 = re.findall("Petrol|Diesel|CNG|LPG",text)
  if regex:
    distance.append(regex[0])
  else:
    distance.append(np.nan)
  if regex2:
    ownership.append(regex2[0])
  else:
    ownership.append(np.nan)
  if regex3:
    fuel.append(regex3[0])
  else:
    fuel.append(np.nan)

for i in soup.find_all("div",class_ = "_18ToE"):
  text = i.text
  regex = re.findall("^₹(\d+,\d+,\d+)",text)
  if regex:
    price.append(regex[0])
  else:
    price.append(np.nan)

for i in soup.find_all("span",class_ = "_2JX5N"):
  text = i.text
  regex = re.findall("₹(\d+,\d+,\d+|\d+,\d+)",text)
  if regex:
    downpayment.append(regex[0])
  else:
    downpayment.append(np.nan)

# %% [markdown]
# ##### mahindra

# %%
url = "https://www.cars24.com/buy-used-mahindra-cars-bangalore/"
req = requests.get(url)
soup = BeautifulSoup(req.text)


for i in soup.find_all("h3",class_="_2lmIw"):
  text = i.text
  regex1 = re.findall(("(\d+)\s"),text)
  regex2 = re.findall("Mahindra",text)
  if regex1:
    model_year.append(regex1[0])
  else:
    model_year.append(np.nan)
  if regex2:
    brand.append(regex2[0])
  else:
    brand.append(np.nan)
  model.append(text[14:])

for i in soup.find_all("ul",class_="_1hOnS"):
  text = i.text
  regex = re.findall("Manual|Automatic",text)
  if regex:
    transmission.append(regex[0])
  else:
    transmission.append(np.nan)

for i in soup.find_all("ul",class_ = "_13yb6"):
  text = i.text
  regex = re.findall("\d+,\d+,\d+|\d+,\d+",text)
  regex2 = re.findall("km(\d+)",text)
  regex3 = re.findall("Petrol|Diesel|CNG|LPG",text)
  if regex:
    distance.append(regex[0])
  else:
    distance.append(np.nan)
  if regex2:
    ownership.append(regex2[0])
  else:
    ownership.append(np.nan)
  if regex3:
    fuel.append(regex3[0])
  else:
    fuel.append(np.nan)

for i in soup.find_all("div",class_ = "_18ToE"):
  text = i.text
  regex = re.findall("^₹(\d+,\d+,\d+)",text)
  if regex:
    price.append(regex[0])
  else:
    price.append(np.nan)

for i in soup.find_all("span",class_ = "_2JX5N"):
  text = i.text
  regex = re.findall("₹(\d+,\d+,\d+|\d+,\d+)",text)
  if regex:
    downpayment.append(regex[0])
  else:
    downpayment.append(np.nan)

# %% [markdown]
# ##### location

# %%
url = "https://www.cars24.com/buy-used-maruti-cars-bangalore/"
req = requests.get(url)
soup = BeautifulSoup(req.text)

for i in soup.find_all("div",class_ ="_1Bq4a"):
  text = i.text

  regex = re.findall("Bangalore",text)
  print(regex)
# Out:
# ['Bangalore']

# %%
size3 = len(brand) - len(Location)
for j in range(0,size3):
  Location.append(regex[0])

# %% [markdown]
# ### hyderabad

# %% [markdown]
# ##### maruti

# %%
url = "https://www.cars24.com/buy-used-maruti-cars-hyderabad/"
req = requests.get(url)
soup = BeautifulSoup(req.text)

for i in soup.find_all("h3",class_="_2lmIw"):
  text = i.text
  regex1 = re.findall(("(\d+)\s"),text)
  regex2 = re.findall("Maruti",text)
  if regex1:
    model_year.append(regex1[0])
  else:
    model_year.append(np.nan)
  if regex2:
    brand.append(regex2[0])
  else:
    brand.append(np.nan)
  model.append(text[12:])

for i in soup.find_all("ul",class_="_1hOnS"):
  text = i.text
  regex = re.findall("Manual|Automatic",text)
  if regex:
    transmission.append(regex[0])
  else:
    transmission.append(np.nan)

for i in soup.find_all("ul",class_ = "_13yb6"):
  text = i.text
  regex = re.findall("\d+,\d+,\d+|\d+,\d+",text)
  regex2 = re.findall("km(\d+)",text)
  regex3 = re.findall("Petrol|Diesel|CNG|LPG",text)
  if regex:
    distance.append(regex[0])
  else:
    distance.append(np.nan)
  if regex2:
    ownership.append(regex2[0])
  else:
    ownership.append(np.nan)
  if regex3:
    fuel.append(regex3[0])
  else:
    fuel.append(np.nan)

for i in soup.find_all("div",class_ = "_18ToE"):
  text = i.text
  regex = re.findall("^₹(\d+,\d+,\d+)",text)
  if regex:
    price.append(regex[0])
  else:
    price.append(np.nan)

for i in soup.find_all("span",class_ = "_2JX5N"):
  text = i.text
  regex = re.findall("₹(\d+,\d+,\d+|\d+,\d+)",text)
  if regex:
    downpayment.append(regex[0])
  else:
    downpayment.append(np.nan)

# %% [markdown]
# ##### hyundai

# %%
url = "https://www.cars24.com/buy-used-hyundai-cars-hyderabad/"
req = requests.get(url)
soup = BeautifulSoup(req.text)


for i in soup.find_all("h3",class_="_2lmIw"):
  text = i.text
  regex1 = re.findall(("(\d+)\s"),text)
  regex2 = re.findall("Hyundai",text)
  if regex1:
    model_year.append(regex1[0])
  else:
    model_year.append(np.nan)
  if regex2:
    brand.append(regex2[0])
  else:
    brand.append(np.nan)
  model.append(text[13:])

for i in soup.find_all("ul",class_="_1hOnS"):
  text = i.text
  regex = re.findall("Manual|Automatic",text)
  if regex:
    transmission.append(regex[0])
  else:
    transmission.append(np.nan)

for i in soup.find_all("ul",class_ = "_13yb6"):
  text = i.text
  regex = re.findall("\d+,\d+,\d+|\d+,\d+",text)
  regex2 = re.findall("km(\d+)",text)
  regex3 = re.findall("Petrol|Diesel|CNG|LPG",text)
  if regex:
    distance.append(regex[0])
  else:
    distance.append(np.nan)
  if regex2:
    ownership.append(regex2[0])
  else:
    ownership.append(np.nan)
  if regex3:
    fuel.append(regex3[0])
  else:
    fuel.append(np.nan)

for i in soup.find_all("div",class_ = "_18ToE"):
  text = i.text
  regex = re.findall("^₹(\d+,\d+,\d+)",text)
  if regex:
    price.append(regex[0])
  else:
    price.append(np.nan)

for i in soup.find_all("span",class_ = "_2JX5N"):
  text = i.text
  regex = re.findall("₹(\d+,\d+,\d+|\d+,\d+)",text)
  if regex:
    downpayment.append(regex[0])
  else:
    downpayment.append(np.nan)

# %% [markdown]
# ##### honda

# %%
url = "https://www.cars24.com/buy-used-honda-cars-hyderabad/"
req = requests.get(url)
soup = BeautifulSoup(req.text)


for i in soup.find_all("h3",class_="_2lmIw"):
  text = i.text
  regex1 = re.findall(("(\d+)\s"),text)
  regex2 = re.findall("Honda",text)
  if regex1:
    model_year.append(regex1[0])
  else:
    model_year.append(np.nan)
  if regex2:
    brand.append(regex2[0])
  else:
    brand.append(np.nan)
  model.append(text[11:])

for i in soup.find_all("ul",class_="_1hOnS"):
  text = i.text
  regex = re.findall("Manual|Automatic",text)
  if regex:
    transmission.append(regex[0])
  else:
    transmission.append(np.nan)

for i in soup.find_all("ul",class_ = "_13yb6"):
  text = i.text
  regex = re.findall("\d+,\d+,\d+|\d+,\d+",text)
  regex2 = re.findall("km(\d+)",text)
  regex3 = re.findall("Petrol|Diesel|CNG|LPG",text)
  if regex:
    distance.append(regex[0])
  else:
    distance.append(np.nan)
  if regex2:
    ownership.append(regex2[0])
  else:
    ownership.append(np.nan)
  if regex3:
    fuel.append(regex3[0])
  else:
    fuel.append(np.nan)

for i in soup.find_all("div",class_ = "_18ToE"):
  text = i.text
  regex = re.findall("^₹(\d+,\d+,\d+)",text)
  if regex:
    price.append(regex[0])
  else:
    price.append(np.nan)

for i in soup.find_all("span",class_ = "_2JX5N"):
  text = i.text
  regex = re.findall("₹(\d+,\d+,\d+|\d+,\d+)",text)
  if regex:
    downpayment.append(regex[0])
  else:
    downpayment.append(np.nan)

# %% [markdown]
# ##### tata

# %%
url = "https://www.cars24.com/buy-used-tata-cars-hyderabad/"
req = requests.get(url)
soup = BeautifulSoup(req.text)


for i in soup.find_all("h3",class_="_2lmIw"):
  text = i.text
  regex1 = re.findall(("(\d+)\s"),text)
  regex2 = re.findall("Tata",text)
  if regex1:
    model_year.append(regex1[0])
  else:
    model_year.append(np.nan)
  if regex2:
    brand.append(regex2[0])
  else:
    brand.append(np.nan)
  model.append(text[10:])

for i in soup.find_all("ul",class_="_1hOnS"):
  text = i.text
  regex = re.findall("Manual|Automatic",text)
  if regex:
    transmission.append(regex[0])
  else:
    transmission.append(np.nan)

for i in soup.find_all("ul",class_ = "_13yb6"):
  text = i.text
  regex = re.findall("\d+,\d+,\d+|\d+,\d+",text)
  regex2 = re.findall("km(\d+)",text)
  regex3 = re.findall("Petrol|Diesel|CNG|LPG",text)
  if regex:
    distance.append(regex[0])
  else:
    distance.append(np.nan)
  if regex2:
    ownership.append(regex2[0])
  else:
    ownership.append(np.nan)
  if regex3:
    fuel.append(regex3[0])
  else:
    fuel.append(np.nan)

for i in soup.find_all("div",class_ = "_18ToE"):
  text = i.text
  regex = re.findall("^₹(\d+,\d+,\d+)",text)
  if regex:
    price.append(regex[0])
  else:
    price.append(np.nan)

for i in soup.find_all("span",class_ = "_2JX5N"):
  text = i.text
  regex = re.findall("₹(\d+,\d+,\d+|\d+,\d+)",text)
  if regex:
    downpayment.append(regex[0])
  else:
    downpayment.append(np.nan)

# %% [markdown]
# ##### mahindra

# %%
url = "https://www.cars24.com/buy-used-mahindra-cars-hyderabad/"
req = requests.get(url)
soup = BeautifulSoup(req.text)


for i in soup.find_all("h3",class_="_2lmIw"):
  text = i.text
  regex1 = re.findall(("(\d+)\s"),text)
  regex2 = re.findall("Mahindra",text)
  if regex1:
    model_year.append(regex1[0])
  else:
    model_year.append(np.nan)
  if regex2:
    brand.append(regex2[0])
  else:
    brand.append(np.nan)
  model.append(text[14:])

for i in soup.find_all("ul",class_="_1hOnS"):
  text = i.text
  regex = re.findall("Manual|Automatic",text)
  if regex:
    transmission.append(regex[0])
  else:
    transmission.append(np.nan)

for i in soup.find_all("ul",class_ = "_13yb6"):
  text = i.text
  regex = re.findall("\d+,\d+,\d+|\d+,\d+",text)
  regex2 = re.findall("km(\d+)",text)
  regex3 = re.findall("Petrol|Diesel|CNG|LPG",text)
  if regex:
    distance.append(regex[0])
  else:
    distance.append(np.nan)
  if regex2:
    ownership.append(regex2[0])
  else:
    ownership.append(np.nan)
  if regex3:
    fuel.append(regex3[0])
  else:
    fuel.append(np.nan)

for i in soup.find_all("div",class_ = "_18ToE"):
  text = i.text
  regex = re.findall("^₹(\d+,\d+,\d+)",text)
  if regex:
    price.append(regex[0])
  else:
    price.append(np.nan)

for i in soup.find_all("span",class_ = "_2JX5N"):
  text = i.text
  regex = re.findall("₹(\d+,\d+,\d+|\d+,\d+)",text)
  if regex:
    downpayment.append(regex[0])
  else:
    downpayment.append(np.nan)

# %% [markdown]
# ##### location

# %%
url = "https://www.cars24.com/buy-used-maruti-cars-hyderabad/"
req = requests.get(url)
soup = BeautifulSoup(req.text)

for i in soup.find_all("div",class_ ="_1Bq4a"):
  text = i.text

  regex = re.findall("Hyderabad",text)
  print(regex)
# Out:
# ['Hyderabad']

# %%
size4 = len(brand) - len(Location)
for j in range(0,size4):
  Location.append(regex[0])

# %% [markdown]
# ### ahmedabad

# %% [markdown]
# ##### maruti

# %%
url = "https://www.cars24.com/buy-used-maruti-cars-ahmedabad/"
req = requests.get(url)
soup = BeautifulSoup(req.text)

for i in soup.find_all("h3",class_="_2lmIw"):
  text = i.text
  regex1 = re.findall(("(\d+)\s"),text)
  regex2 = re.findall("Maruti",text)
  if regex1:
    model_year.append(regex1[0])
  else:
    model_year.append(np.nan)
  if regex2:
    brand.append(regex2[0])
  else:
    brand.append(np.nan)
  model.append(text[12:])

for i in soup.find_all("ul",class_="_1hOnS"):
  text = i.text
  regex = re.findall("Manual|Automatic",text)
  if regex:
    transmission.append(regex[0])
  else:
    transmission.append(np.nan)

for i in soup.find_all("ul",class_ = "_13yb6"):
  text = i.text
  regex = re.findall("\d+,\d+,\d+|\d+,\d+",text)
  regex2 = re.findall("km(\d+)",text)
  regex3 = re.findall("Petrol|Diesel|CNG|LPG",text)
  if regex:
    distance.append(regex[0])
  else:
    distance.append(np.nan)
  if regex2:
    ownership.append(regex2[0])
  else:
    ownership.append(np.nan)
  if regex3:
    fuel.append(regex3[0])
  else:
    fuel.append(np.nan)

for i in soup.find_all("div",class_ = "_18ToE"):
  text = i.text
  regex = re.findall("^₹(\d+,\d+,\d+)",text)
  if regex:
    price.append(regex[0])
  else:
    price.append(np.nan)

for i in soup.find_all("span",class_ = "_2JX5N"):
  text = i.text
  regex = re.findall("₹(\d+,\d+,\d+|\d+,\d+)",text)
  if regex:
    downpayment.append(regex[0])
  else:
    downpayment.append(np.nan)

# %% [markdown]
# ##### hyundai

# %%
url = "https://www.cars24.com/buy-used-hyundai-cars-ahmedabad/"
req = requests.get(url)
soup = BeautifulSoup(req.text)


for i in soup.find_all("h3",class_="_2lmIw"):
  text = i.text
  regex1 = re.findall(("(\d+)\s"),text)
  regex2 = re.findall("Hyundai",text)
  if regex1:
    model_year.append(regex1[0])
  else:
    model_year.append(np.nan)
  if regex2:
    brand.append(regex2[0])
  else:
    brand.append(np.nan)
  model.append(text[13:])

for i in soup.find_all("ul",class_="_1hOnS"):
  text = i.text
  regex = re.findall("Manual|Automatic",text)
  if regex:
    transmission.append(regex[0])
  else:
    transmission.append(np.nan)

for i in soup.find_all("ul",class_ = "_13yb6"):
  text = i.text
  regex = re.findall("\d+,\d+,\d+|\d+,\d+",text)
  regex2 = re.findall("km(\d+)",text)
  regex3 = re.findall("Petrol|Diesel|CNG|LPG",text)
  if regex:
    distance.append(regex[0])
  else:
    distance.append(np.nan)
  if regex2:
    ownership.append(regex2[0])
  else:
    ownership.append(np.nan)
  if regex3:
    fuel.append(regex3[0])
  else:
    fuel.append(np.nan)

for i in soup.find_all("div",class_ = "_18ToE"):
  text = i.text
  regex = re.findall("^₹(\d+,\d+,\d+)",text)
  if regex:
    price.append(regex[0])
  else:
    price.append(np.nan)

for i in soup.find_all("span",class_ = "_2JX5N"):
  text = i.text
  regex = re.findall("₹(\d+,\d+,\d+|\d+,\d+)",text)
  if regex:
    downpayment.append(regex[0])
  else:
    downpayment.append(np.nan)

# %% [markdown]
# ##### honda

# %%
url = "https://www.cars24.com/buy-used-honda-cars-ahmedabad/"
req = requests.get(url)
soup = BeautifulSoup(req.text)


for i in soup.find_all("h3",class_="_2lmIw"):
  text = i.text
  regex1 = re.findall(("(\d+)\s"),text)
  regex2 = re.findall("Honda",text)
  if regex1:
    model_year.append(regex1[0])
  else:
    model_year.append(np.nan)
  if regex2:
    brand.append(regex2[0])
  else:
    brand.append(np.nan)
  model.append(text[11:])

for i in soup.find_all("ul",class_="_1hOnS"):
  text = i.text
  regex = re.findall("Manual|Automatic",text)
  if regex:
    transmission.append(regex[0])
  else:
    transmission.append(np.nan)

for i in soup.find_all("ul",class_ = "_13yb6"):
  text = i.text
  regex = re.findall("\d+,\d+,\d+|\d+,\d+",text)
  regex2 = re.findall("km(\d+)",text)
  regex3 = re.findall("Petrol|Diesel|CNG|LPG",text)
  if regex:
    distance.append(regex[0])
  else:
    distance.append(np.nan)
  if regex2:
    ownership.append(regex2[0])
  else:
    ownership.append(np.nan)
  if regex3:
    fuel.append(regex3[0])
  else:
    fuel.append(np.nan)

for i in soup.find_all("div",class_ = "_18ToE"):
  text = i.text
  regex = re.findall("^₹(\d+,\d+,\d+)",text)
  if regex:
    price.append(regex[0])
  else:
    price.append(np.nan)

for i in soup.find_all("span",class_ = "_2JX5N"):
  text = i.text
  regex = re.findall("₹(\d+,\d+,\d+|\d+,\d+)",text)
  if regex:
    downpayment.append(regex[0])
  else:
    downpayment.append(np.nan)

# %% [markdown]
# ##### tata

# %%
url = "https://www.cars24.com/buy-used-tata-cars-ahmedabad/"
req = requests.get(url)
soup = BeautifulSoup(req.text)


for i in soup.find_all("h3",class_="_2lmIw"):
  text = i.text
  regex1 = re.findall(("(\d+)\s"),text)
  regex2 = re.findall("Tata",text)
  if regex1:
    model_year.append(regex1[0])
  else:
    model_year.append(np.nan)
  if regex2:
    brand.append(regex2[0])
  else:
    brand.append(np.nan)
  model.append(text[10:])

for i in soup.find_all("ul",class_="_1hOnS"):
  text = i.text
  regex = re.findall("Manual|Automatic",text)
  if regex:
    transmission.append(regex[0])
  else:
    transmission.append(np.nan)

for i in soup.find_all("ul",class_ = "_13yb6"):
  text = i.text
  regex = re.findall("\d+,\d+,\d+|\d+,\d+",text)
  regex2 = re.findall("km(\d+)",text)
  regex3 = re.findall("Petrol|Diesel|CNG|LPG",text)
  if regex:
    distance.append(regex[0])
  else:
    distance.append(np.nan)
  if regex2:
    ownership.append(regex2[0])
  else:
    ownership.append(np.nan)
  if regex3:
    fuel.append(regex3[0])
  else:
    fuel.append(np.nan)

for i in soup.find_all("div",class_ = "_18ToE"):
  text = i.text
  regex = re.findall("^₹(\d+,\d+,\d+)",text)
  if regex:
    price.append(regex[0])
  else:
    price.append(np.nan)

for i in soup.find_all("span",class_ = "_2JX5N"):
  text = i.text
  regex = re.findall("₹(\d+,\d+,\d+|\d+,\d+)",text)
  if regex:
    downpayment.append(regex[0])
  else:
    downpayment.append(np.nan)

# %% [markdown]
# ##### mahindra

# %%
url = "https://www.cars24.com/buy-used-mahindra-cars-ahmedabad"
req = requests.get(url)
soup = BeautifulSoup(req.text)


for i in soup.find_all("h3",class_="_2lmIw"):
  text = i.text
  regex1 = re.findall(("(\d+)\s"),text)
  regex2 = re.findall("Mahindra",text)
  if regex1:
    model_year.append(regex1[0])
  else:
    model_year.append(np.nan)
  if regex2:
    brand.append(regex2[0])
  else:
    brand.append(np.nan)
  model.append(text[14:])

for i in soup.find_all("ul",class_="_1hOnS"):
  text = i.text
  regex = re.findall("Manual|Automatic",text)
  if regex:
    transmission.append(regex[0])
  else:
    transmission.append(np.nan)

for i in soup.find_all("ul",class_ = "_13yb6"):
  text = i.text
  regex = re.findall("\d+,\d+,\d+|\d+,\d+",text)
  regex2 = re.findall("km(\d+)",text)
  regex3 = re.findall("Petrol|Diesel|CNG|LPG",text)
  if regex:
    distance.append(regex[0])
  else:
    distance.append(np.nan)
  if regex2:
    ownership.append(regex2[0])
  else:
    ownership.append(np.nan)
  if regex3:
    fuel.append(regex3[0])
  else:
    fuel.append(np.nan)

for i in soup.find_all("div",class_ = "_18ToE"):
  text = i.text
  regex = re.findall("^₹(\d+,\d+,\d+)",text)
  if regex:
    price.append(regex[0])
  else:
    price.append(np.nan)

for i in soup.find_all("span",class_ = "_2JX5N"):
  text = i.text
  regex = re.findall("₹(\d+,\d+,\d+|\d+,\d+)",text)
  if regex:
    downpayment.append(regex[0])
  else:
    downpayment.append(np.nan)

# %% [markdown]
# ##### location

# %%
url = "https://www.cars24.com/buy-used-maruti-cars-ahmedabad/"
req = requests.get(url)
soup = BeautifulSoup(req.text)

for i in soup.find_all("div",class_ ="_1Bq4a"):
  text = i.text

  regex = re.findall("Ahmedabad",text)
  print(regex)
# Out:
# ['Ahmedabad']

# %%
size4 = len(brand) - len(Location)
for j in range(0,size4):
  Location.append(regex[0])

# %% [markdown]
# ### chennai

# %% [markdown]
# ##### maruti

# %%
url = "https://www.cars24.com/buy-used-maruti-cars-chennai/"
req = requests.get(url)
soup = BeautifulSoup(req.text)

for i in soup.find_all("h3",class_="_2lmIw"):
  text = i.text
  regex1 = re.findall(("(\d+)\s"),text)
  regex2 = re.findall("Maruti",text)
  if regex1:
    model_year.append(regex1[0])
  else:
    model_year.append(np.nan)
  if regex2:
    brand.append(regex2[0])
  else:
    brand.append(np.nan)
  model.append(text[12:])

for i in soup.find_all("ul",class_="_1hOnS"):
  text = i.text
  regex = re.findall("Manual|Automatic",text)
  if regex:
    transmission.append(regex[0])
  else:
    transmission.append(np.nan)

for i in soup.find_all("ul",class_ = "_13yb6"):
  text = i.text
  regex = re.findall("\d+,\d+,\d+|\d+,\d+",text)
  regex2 = re.findall("km(\d+)",text)
  regex3 = re.findall("Petrol|Diesel|CNG|LPG",text)
  if regex:
    distance.append(regex[0])
  else:
    distance.append(np.nan)
  if regex2:
    ownership.append(regex2[0])
  else:
    ownership.append(np.nan)
  if regex3:
    fuel.append(regex3[0])
  else:
    fuel.append(np.nan)

for i in soup.find_all("div",class_ = "_18ToE"):
  text = i.text
  regex = re.findall("^₹(\d+,\d+,\d+)",text)
  if regex:
    price.append(regex[0])
  else:
    price.append(np.nan)

for i in soup.find_all("span",class_ = "_2JX5N"):
  text = i.text
  regex = re.findall("₹(\d+,\d+,\d+|\d+,\d+)",text)
  if regex:
    downpayment.append(regex[0])
  else:
    downpayment.append(np.nan)

# %% [markdown]
# ##### hyundai

# %%
url = "https://www.cars24.com/buy-used-hyundai-cars-chennai/"
req = requests.get(url)
soup = BeautifulSoup(req.text)


for i in soup.find_all("h3",class_="_2lmIw"):
  text = i.text
  regex1 = re.findall(("(\d+)\s"),text)
  regex2 = re.findall("Hyundai",text)
  if regex1:
    model_year.append(regex1[0])
  else:
    model_year.append(np.nan)
  if regex2:
    brand.append(regex2[0])
  else:
    brand.append(np.nan)
  model.append(text[13:])

for i in soup.find_all("ul",class_="_1hOnS"):
  text = i.text
  regex = re.findall("Manual|Automatic",text)
  if regex:
    transmission.append(regex[0])
  else:
    transmission.append(np.nan)

for i in soup.find_all("ul",class_ = "_13yb6"):
  text = i.text
  regex = re.findall("\d+,\d+,\d+|\d+,\d+",text)
  regex2 = re.findall("km(\d+)",text)
  regex3 = re.findall("Petrol|Diesel|CNG|LPG",text)
  if regex:
    distance.append(regex[0])
  else:
    distance.append(np.nan)
  if regex2:
    ownership.append(regex2[0])
  else:
    ownership.append(np.nan)
  if regex3:
    fuel.append(regex3[0])
  else:
    fuel.append(np.nan)

for i in soup.find_all("div",class_ = "_18ToE"):
  text = i.text
  regex = re.findall("^₹(\d+,\d+,\d+)",text)
  if regex:
    price.append(regex[0])
  else:
    price.append(np.nan)

for i in soup.find_all("span",class_ = "_2JX5N"):
  text = i.text
  regex = re.findall("₹(\d+,\d+,\d+|\d+,\d+)",text)
  if regex:
    downpayment.append(regex[0])
  else:
    downpayment.append(np.nan)

# %% [markdown]
# ##### honda

# %%
url = "https://www.cars24.com/buy-used-honda-cars-chennai/"
req = requests.get(url)
soup = BeautifulSoup(req.text)


for i in soup.find_all("h3",class_="_2lmIw"):
  text = i.text
  regex1 = re.findall(("(\d+)\s"),text)
  regex2 = re.findall("Honda",text)
  if regex1:
    model_year.append(regex1[0])
  else:
    model_year.append(np.nan)
  if regex2:
    brand.append(regex2[0])
  else:
    brand.append(np.nan)
  model.append(text[11:])

for i in soup.find_all("ul",class_="_1hOnS"):
  text = i.text
  regex = re.findall("Manual|Automatic",text)
  if regex:
    transmission.append(regex[0])
  else:
    transmission.append(np.nan)

for i in soup.find_all("ul",class_ = "_13yb6"):
  text = i.text
  regex = re.findall("\d+,\d+,\d+|\d+,\d+",text)
  regex2 = re.findall("km(\d+)",text)
  regex3 = re.findall("Petrol|Diesel|CNG|LPG",text)
  if regex:
    distance.append(regex[0])
  else:
    distance.append(np.nan)
  if regex2:
    ownership.append(regex2[0])
  else:
    ownership.append(np.nan)
  if regex3:
    fuel.append(regex3[0])
  else:
    fuel.append(np.nan)

for i in soup.find_all("div",class_ = "_18ToE"):
  text = i.text
  regex = re.findall("^₹(\d+,\d+,\d+)",text)
  if regex:
    price.append(regex[0])
  else:
    price.append(np.nan)

for i in soup.find_all("span",class_ = "_2JX5N"):
  text = i.text
  regex = re.findall("₹(\d+,\d+,\d+|\d+,\d+)",text)
  if regex:
    downpayment.append(regex[0])
  else:
    downpayment.append(np.nan)

# %% [markdown]
# ##### tata

# %%
url = "https://www.cars24.com/buy-used-tata-cars-chennai/"
req = requests.get(url)
soup = BeautifulSoup(req.text)


for i in soup.find_all("h3",class_="_2lmIw"):
  text = i.text
  regex1 = re.findall(("(\d+)\s"),text)
  regex2 = re.findall("Tata",text)
  if regex1:
    model_year.append(regex1[0])
  else:
    model_year.append(np.nan)
  if regex2:
    brand.append(regex2[0])
  else:
    brand.append(np.nan)
  model.append(text[10:])

for i in soup.find_all("ul",class_="_1hOnS"):
  text = i.text
  regex = re.findall("Manual|Automatic",text)
  if regex:
    transmission.append(regex[0])
  else:
    transmission.append(np.nan)

for i in soup.find_all("ul",class_ = "_13yb6"):
  text = i.text
  regex = re.findall("\d+,\d+,\d+|\d+,\d+",text)
  regex2 = re.findall("km(\d+)",text)
  regex3 = re.findall("Petrol|Diesel|CNG|LPG",text)
  if regex:
    distance.append(regex[0])
  else:
    distance.append(np.nan)
  if regex2:
    ownership.append(regex2[0])
  else:
    ownership.append(np.nan)
  if regex3:
    fuel.append(regex3[0])
  else:
    fuel.append(np.nan)

for i in soup.find_all("div",class_ = "_18ToE"):
  text = i.text
  regex = re.findall("^₹(\d+,\d+,\d+)",text)
  if regex:
    price.append(regex[0])
  else:
    price.append(np.nan)

for i in soup.find_all("span",class_ = "_2JX5N"):
  text = i.text
  regex = re.findall("₹(\d+,\d+,\d+|\d+,\d+)",text)
  if regex:
    downpayment.append(regex[0])
  else:
    downpayment.append(np.nan)

# %% [markdown]
# ##### mahindra

# %%
url = "https://www.cars24.com/buy-used-mahindra-cars-chennai/"
req = requests.get(url)
soup = BeautifulSoup(req.text)


for i in soup.find_all("h3",class_="_2lmIw"):
  text = i.text
  regex1 = re.findall(("(\d+)\s"),text)
  regex2 = re.findall("Mahindra",text)
  if regex1:
    model_year.append(regex1[0])
  else:
    model_year.append(np.nan)
  if regex2:
    brand.append(regex2[0])
  else:
    brand.append(np.nan)
  model.append(text[14:])

for i in soup.find_all("ul",class_="_1hOnS"):
  text = i.text
  regex = re.findall("Manual|Automatic",text)
  if regex:
    transmission.append(regex[0])
  else:
    transmission.append(np.nan)

for i in soup.find_all("ul",class_ = "_13yb6"):
  text = i.text
  regex = re.findall("\d+,\d+,\d+|\d+,\d+",text)
  regex2 = re.findall("km(\d+)",text)
  regex3 = re.findall("Petrol|Diesel|CNG|LPG",text)
  if regex:
    distance.append(regex[0])
  else:
    distance.append(np.nan)
  if regex2:
    ownership.append(regex2[0])
  else:
    ownership.append(np.nan)
  if regex3:
    fuel.append(regex3[0])
  else:
    fuel.append(np.nan)

for i in soup.find_all("div",class_ = "_18ToE"):
  text = i.text
  regex = re.findall("^₹(\d+,\d+,\d+)",text)
  if regex:
    price.append(regex[0])
  else:
    price.append(np.nan)

for i in soup.find_all("span",class_ = "_2JX5N"):
  text = i.text
  regex = re.findall("₹(\d+,\d+,\d+|\d+,\d+)",text)
  if regex:
    downpayment.append(regex[0])
  else:
    downpayment.append(np.nan)

# %% [markdown]
# ##### location

# %%
url = "https://www.cars24.com/buy-used-maruti-cars-chennai/"
req = requests.get(url)
soup = BeautifulSoup(req.text)

for i in soup.find_all("div",class_ ="_1Bq4a"):
  text = i.text

  regex = re.findall("Chennai",text)
  print(regex)
# Out:
# ['Chennai']

# %%
size6 = len(brand) - len(Location)
for j in range(0,size6):
  Location.append(regex[0])

# %% [markdown]
# ### kolkata

# %% [markdown]
# ##### maruti

# %%
url = "https://www.cars24.com/buy-used-maruti-cars-kolkata/"
req = requests.get(url)
soup = BeautifulSoup(req.text)

for i in soup.find_all("h3",class_="_2lmIw"):
  text = i.text
  regex1 = re.findall(("(\d+)\s"),text)
  regex2 = re.findall("Maruti",text)
  if regex1:
    model_year.append(regex1[0])
  else:
    model_year.append(np.nan)
  if regex2:
    brand.append(regex2[0])
  else:
    brand.append(np.nan)
  model.append(text[12:])

for i in soup.find_all("ul",class_="_1hOnS"):
  text = i.text
  regex = re.findall("Manual|Automatic",text)
  if regex:
    transmission.append(regex[0])
  else:
    transmission.append(np.nan)

for i in soup.find_all("ul",class_ = "_13yb6"):
  text = i.text
  regex = re.findall("\d+,\d+,\d+|\d+,\d+",text)
  regex2 = re.findall("km(\d+)",text)
  regex3 = re.findall("Petrol|Diesel|CNG|LPG",text)
  if regex:
    distance.append(regex[0])
  else:
    distance.append(np.nan)
  if regex2:
    ownership.append(regex2[0])
  else:
    ownership.append(np.nan)
  if regex3:
    fuel.append(regex3[0])
  else:
    fuel.append(np.nan)

for i in soup.find_all("div",class_ = "_18ToE"):
  text = i.text
  regex = re.findall("^₹(\d+,\d+,\d+)",text)
  if regex:
    price.append(regex[0])
  else:
    price.append(np.nan)

for i in soup.find_all("span",class_ = "_2JX5N"):
  text = i.text
  regex = re.findall("₹(\d+,\d+,\d+|\d+,\d+)",text)
  if regex:
    downpayment.append(regex[0])
  else:
    downpayment.append(np.nan)

# %% [markdown]
# ##### hyundai

# %%
url = "https://www.cars24.com/buy-used-hyundai-cars-kolkata/"
req = requests.get(url)
soup = BeautifulSoup(req.text)


for i in soup.find_all("h3",class_="_2lmIw"):
  text = i.text
  regex1 = re.findall(("(\d+)\s"),text)
  regex2 = re.findall("Hyundai",text)
  if regex1:
    model_year.append(regex1[0])
  else:
    model_year.append(np.nan)
  if regex2:
    brand.append(regex2[0])
  else:
    brand.append(np.nan)
  model.append(text[13:])

for i in soup.find_all("ul",class_="_1hOnS"):
  text = i.text
  regex = re.findall("Manual|Automatic",text)
  if regex:
    transmission.append(regex[0])
  else:
    transmission.append(np.nan)

for i in soup.find_all("ul",class_ = "_13yb6"):
  text = i.text
  regex = re.findall("\d+,\d+,\d+|\d+,\d+",text)
  regex2 = re.findall("km(\d+)",text)
  regex3 = re.findall("Petrol|Diesel|CNG|LPG",text)
  if regex:
    distance.append(regex[0])
  else:
    distance.append(np.nan)
  if regex2:
    ownership.append(regex2[0])
  else:
    ownership.append(np.nan)
  if regex3:
    fuel.append(regex3[0])
  else:
    fuel.append(np.nan)

for i in soup.find_all("div",class_ = "_18ToE"):
  text = i.text
  regex = re.findall("^₹(\d+,\d+,\d+)",text)
  if regex:
    price.append(regex[0])
  else:
    price.append(np.nan)

for i in soup.find_all("span",class_ = "_2JX5N"):
  text = i.text
  regex = re.findall("₹(\d+,\d+,\d+|\d+,\d+)",text)
  if regex:
    downpayment.append(regex[0])
  else:
    downpayment.append(np.nan)

# %% [markdown]
# ##### honda

# %%
url = "https://www.cars24.com/buy-used-honda-cars-kolkata/"
req = requests.get(url)
soup = BeautifulSoup(req.text)


for i in soup.find_all("h3",class_="_2lmIw"):
  text = i.text
  regex1 = re.findall(("(\d+)\s"),text)
  regex2 = re.findall("Honda",text)
  if regex1:
    model_year.append(regex1[0])
  else:
    model_year.append(np.nan)
  if regex2:
    brand.append(regex2[0])
  else:
    brand.append(np.nan)
  model.append(text[11:])

for i in soup.find_all("ul",class_="_1hOnS"):
  text = i.text
  regex = re.findall("Manual|Automatic",text)
  if regex:
    transmission.append(regex[0])
  else:
    transmission.append(np.nan)

for i in soup.find_all("ul",class_ = "_13yb6"):
  text = i.text
  regex = re.findall("\d+,\d+,\d+|\d+,\d+",text)
  regex2 = re.findall("km(\d+)",text)
  regex3 = re.findall("Petrol|Diesel|CNG|LPG",text)
  if regex:
    distance.append(regex[0])
  else:
    distance.append(np.nan)
  if regex2:
    ownership.append(regex2[0])
  else:
    ownership.append(np.nan)
  if regex3:
    fuel.append(regex3[0])
  else:
    fuel.append(np.nan)

for i in soup.find_all("div",class_ = "_18ToE"):
  text = i.text
  regex = re.findall("^₹(\d+,\d+,\d+)",text)
  if regex:
    price.append(regex[0])
  else:
    price.append(np.nan)

for i in soup.find_all("span",class_ = "_2JX5N"):
  text = i.text
  regex = re.findall("₹(\d+,\d+,\d+|\d+,\d+)",text)
  if regex:
    downpayment.append(regex[0])
  else:
    downpayment.append(np.nan)

# %% [markdown]
# ##### tata

# %%
url = "https://www.cars24.com/buy-used-tata-cars-kolkata/"
req = requests.get(url)
soup = BeautifulSoup(req.text)


for i in soup.find_all("h3",class_="_2lmIw"):
  text = i.text
  regex1 = re.findall(("(\d+)\s"),text)
  regex2 = re.findall("Tata",text)
  if regex1:
    model_year.append(regex1[0])
  else:
    model_year.append(np.nan)
  if regex2:
    brand.append(regex2[0])
  else:
    brand.append(np.nan)
  model.append(text[10:])

for i in soup.find_all("ul",class_="_1hOnS"):
  text = i.text
  regex = re.findall("Manual|Automatic",text)
  if regex:
    transmission.append(regex[0])
  else:
    transmission.append(np.nan)

for i in soup.find_all("ul",class_ = "_13yb6"):
  text = i.text
  regex = re.findall("\d+,\d+,\d+|\d+,\d+",text)
  regex2 = re.findall("km(\d+)",text)
  regex3 = re.findall("Petrol|Diesel|CNG|LPG",text)
  if regex:
    distance.append(regex[0])
  else:
    distance.append(np.nan)
  if regex2:
    ownership.append(regex2[0])
  else:
    ownership.append(np.nan)
  if regex3:
    fuel.append(regex3[0])
  else:
    fuel.append(np.nan)

for i in soup.find_all("div",class_ = "_18ToE"):
  text = i.text
  regex = re.findall("^₹(\d+,\d+,\d+)",text)
  if regex:
    price.append(regex[0])
  else:
    price.append(np.nan)

for i in soup.find_all("span",class_ = "_2JX5N"):
  text = i.text
  regex = re.findall("₹(\d+,\d+,\d+|\d+,\d+)",text)
  if regex:
    downpayment.append(regex[0])
  else:
    downpayment.append(np.nan)

# %% [markdown]
# ##### mahindra

# %%
url = "https://www.cars24.com/buy-used-mahindra-cars-kolkata/"
req = requests.get(url)
soup = BeautifulSoup(req.text)


for i in soup.find_all("h3",class_="_2lmIw"):
  text = i.text
  regex1 = re.findall(("(\d+)\s"),text)
  regex2 = re.findall("Mahindra",text)
  if regex1:
    model_year.append(regex1[0])
  else:
    model_year.append(np.nan)
  if regex2:
    brand.append(regex2[0])
  else:
    brand.append(np.nan)
  model.append(text[14:])

for i in soup.find_all("ul",class_="_1hOnS"):
  text = i.text
  regex = re.findall("Manual|Automatic",text)
  if regex:
    transmission.append(regex[0])
  else:
    transmission.append(np.nan)

for i in soup.find_all("ul",class_ = "_13yb6"):
  text = i.text
  regex = re.findall("\d+,\d+,\d+|\d+,\d+",text)
  regex2 = re.findall("km(\d+)",text)
  regex3 = re.findall("Petrol|Diesel|CNG|LPG",text)
  if regex:
    distance.append(regex[0])
  else:
    distance.append(np.nan)
  if regex2:
    ownership.append(regex2[0])
  else:
    ownership.append(np.nan)
  if regex3:
    fuel.append(regex3[0])
  else:
    fuel.append(np.nan)

for i in soup.find_all("div",class_ = "_18ToE"):
  text = i.text
  regex = re.findall("^₹(\d+,\d+,\d+)",text)
  if regex:
    price.append(regex[0])
  else:
    price.append(np.nan)

for i in soup.find_all("span",class_ = "_2JX5N"):
  text = i.text
  regex = re.findall("₹(\d+,\d+,\d+|\d+,\d+)",text)
  if regex:
    downpayment.append(regex[0])
  else:
    downpayment.append(np.nan)

# %% [markdown]
# ##### location

# %%
url = "https://www.cars24.com/buy-used-maruti-cars-kolkata/"
req = requests.get(url)
soup = BeautifulSoup(req.text)

for i in soup.find_all("div",class_ ="_1Bq4a"):
  text = i.text

  regex = re.findall("Kolkata",text)
  print(regex)
# Out:
# ['Kolkata']

# %%
size7 = len(brand) - len(Location)
for j in range(0,size7):
  Location.append(regex[0])

# %% [markdown]
# ### surat

# %% [markdown]
# ##### maruti

# %%
url = "https://www.cars24.com/buy-used-maruti-cars-surat/"
req = requests.get(url)
soup = BeautifulSoup(req.text)

for i in soup.find_all("h3",class_="_2lmIw"):
  text = i.text
  regex1 = re.findall(("(\d+)\s"),text)
  regex2 = re.findall("Maruti",text)
  if regex1:
    model_year.append(regex1[0])
  else:
    model_year.append(np.nan)
  if regex2:
    brand.append(regex2[0])
  else:
    brand.append(np.nan)
  model.append(text[12:])

for i in soup.find_all("ul",class_="_1hOnS"):
  text = i.text
  regex = re.findall("Manual|Automatic",text)
  if regex:
    transmission.append(regex[0])
  else:
    transmission.append(np.nan)

for i in soup.find_all("ul",class_ = "_13yb6"):
  text = i.text
  regex = re.findall("\d+,\d+,\d+|\d+,\d+",text)
  regex2 = re.findall("km(\d+)",text)
  regex3 = re.findall("Petrol|Diesel|CNG|LPG",text)
  if regex:
    distance.append(regex[0])
  else:
    distance.append(np.nan)
  if regex2:
    ownership.append(regex2[0])
  else:
    ownership.append(np.nan)
  if regex3:
    fuel.append(regex3[0])
  else:
    fuel.append(np.nan)

for i in soup.find_all("div",class_ = "_18ToE"):
  text = i.text
  regex = re.findall("^₹(\d+,\d+,\d+)",text)
  if regex:
    price.append(regex[0])
  else:
    price.append(np.nan)

for i in soup.find_all("span",class_ = "_2JX5N"):
  text = i.text
  regex = re.findall("₹(\d+,\d+,\d+|\d+,\d+)",text)
  if regex:
    downpayment.append(regex[0])
  else:
    downpayment.append(np.nan)

# %% [markdown]
# ##### hyundai

# %%
url = "https://www.cars24.com/buy-used-hyundai-cars-surat/"
req = requests.get(url)
soup = BeautifulSoup(req.text)


for i in soup.find_all("h3",class_="_2lmIw"):
  text = i.text
  regex1 = re.findall(("(\d+)\s"),text)
  regex2 = re.findall("Hyundai",text)
  if regex1:
    model_year.append(regex1[0])
  else:
    model_year.append(np.nan)
  if regex2:
    brand.append(regex2[0])
  else:
    brand.append(np.nan)
  model.append(text[13:])

for i in soup.find_all("ul",class_="_1hOnS"):
  text = i.text
  regex = re.findall("Manual|Automatic",text)
  if regex:
    transmission.append(regex[0])
  else:
    transmission.append(np.nan)

for i in soup.find_all("ul",class_ = "_13yb6"):
  text = i.text
  regex = re.findall("\d+,\d+,\d+|\d+,\d+",text)
  regex2 = re.findall("km(\d+)",text)
  regex3 = re.findall("Petrol|Diesel|CNG|LPG",text)
  if regex:
    distance.append(regex[0])
  else:
    distance.append(np.nan)
  if regex2:
    ownership.append(regex2[0])
  else:
    ownership.append(np.nan)
  if regex3:
    fuel.append(regex3[0])
  else:
    fuel.append(np.nan)

for i in soup.find_all("div",class_ = "_18ToE"):
  text = i.text
  regex = re.findall("^₹(\d+,\d+,\d+)",text)
  if regex:
    price.append(regex[0])
  else:
    price.append(np.nan)

for i in soup.find_all("span",class_ = "_2JX5N"):
  text = i.text
  regex = re.findall("₹(\d+,\d+,\d+|\d+,\d+)",text)
  if regex:
    downpayment.append(regex[0])
  else:
    downpayment.append(np.nan)

# %% [markdown]
# ##### honda

# %%
url = "https://www.cars24.com/buy-used-honda-cars-surat/"
req = requests.get(url)
soup = BeautifulSoup(req.text)


for i in soup.find_all("h3",class_="_2lmIw"):
  text = i.text
  regex1 = re.findall(("(\d+)\s"),text)
  regex2 = re.findall("Honda",text)
  if regex1:
    model_year.append(regex1[0])
  else:
    model_year.append(np.nan)
  if regex2:
    brand.append(regex2[0])
  else:
    brand.append(np.nan)
  model.append(text[11:])

for i in soup.find_all("ul",class_="_1hOnS"):
  text = i.text
  regex = re.findall("Manual|Automatic",text)
  if regex:
    transmission.append(regex[0])
  else:
    transmission.append(np.nan)

for i in soup.find_all("ul",class_ = "_13yb6"):
  text = i.text
  regex = re.findall("\d+,\d+,\d+|\d+,\d+",text)
  regex2 = re.findall("km(\d+)",text)
  regex3 = re.findall("Petrol|Diesel|CNG|LPG",text)
  if regex:
    distance.append(regex[0])
  else:
    distance.append(np.nan)
  if regex2:
    ownership.append(regex2[0])
  else:
    ownership.append(np.nan)
  if regex3:
    fuel.append(regex3[0])
  else:
    fuel.append(np.nan)

for i in soup.find_all("div",class_ = "_18ToE"):
  text = i.text
  regex = re.findall("^₹(\d+,\d+,\d+)",text)
  if regex:
    price.append(regex[0])
  else:
    price.append(np.nan)

for i in soup.find_all("span",class_ = "_2JX5N"):
  text = i.text
  regex = re.findall("₹(\d+,\d+,\d+|\d+,\d+)",text)
  if regex:
    downpayment.append(regex[0])
  else:
    downpayment.append(np.nan)

# %% [markdown]
# ##### tata

# %%
url = "https://www.cars24.com/buy-used-tata-cars-surat/"
req = requests.get(url)
soup = BeautifulSoup(req.text)


for i in soup.find_all("h3",class_="_2lmIw"):
  text = i.text
  regex1 = re.findall(("(\d+)\s"),text)
  regex2 = re.findall("Tata",text)
  if regex1:
    model_year.append(regex1[0])
  else:
    model_year.append(np.nan)
  if regex2:
    brand.append(regex2[0])
  else:
    brand.append(np.nan)
  model.append(text[10:])

for i in soup.find_all("ul",class_="_1hOnS"):
  text = i.text
  regex = re.findall("Manual|Automatic",text)
  if regex:
    transmission.append(regex[0])
  else:
    transmission.append(np.nan)

for i in soup.find_all("ul",class_ = "_13yb6"):
  text = i.text
  regex = re.findall("\d+,\d+,\d+|\d+,\d+",text)
  regex2 = re.findall("km(\d+)",text)
  regex3 = re.findall("Petrol|Diesel|CNG|LPG",text)
  if regex:
    distance.append(regex[0])
  else:
    distance.append(np.nan)
  if regex2:
    ownership.append(regex2[0])
  else:
    ownership.append(np.nan)
  if regex3:
    fuel.append(regex3[0])
  else:
    fuel.append(np.nan)

for i in soup.find_all("div",class_ = "_18ToE"):
  text = i.text
  regex = re.findall("^₹(\d+,\d+,\d+)",text)
  if regex:
    price.append(regex[0])
  else:
    price.append(np.nan)

for i in soup.find_all("span",class_ = "_2JX5N"):
  text = i.text
  regex = re.findall("₹(\d+,\d+,\d+|\d+,\d+)",text)
  if regex:
    downpayment.append(regex[0])
  else:
    downpayment.append(np.nan)

# %% [markdown]
# ##### mahindra

# %%
url = "https://www.cars24.com/buy-used-mahindra-cars-surat/"
req = requests.get(url)
soup = BeautifulSoup(req.text)


for i in soup.find_all("h3",class_="_2lmIw"):
  text = i.text
  regex1 = re.findall(("(\d+)\s"),text)
  regex2 = re.findall("Mahindra",text)
  if regex1:
    model_year.append(regex1[0])
  else:
    model_year.append(np.nan)
  if regex2:
    brand.append(regex2[0])
  else:
    brand.append(np.nan)
  model.append(text[14:])

for i in soup.find_all("ul",class_="_1hOnS"):
  text = i.text
  regex = re.findall("Manual|Automatic",text)
  if regex:
    transmission.append(regex[0])
  else:
    transmission.append(np.nan)

for i in soup.find_all("ul",class_ = "_13yb6"):
  text = i.text
  regex = re.findall("\d+,\d+,\d+|\d+,\d+",text)
  regex2 = re.findall("km(\d+)",text)
  regex3 = re.findall("Petrol|Diesel|CNG|LPG",text)
  if regex:
    distance.append(regex[0])
  else:
    distance.append(np.nan)
  if regex2:
    ownership.append(regex2[0])
  else:
    ownership.append(np.nan)
  if regex3:
    fuel.append(regex3[0])
  else:
    fuel.append(np.nan)

for i in soup.find_all("div",class_ = "_18ToE"):
  text = i.text
  regex = re.findall("^₹(\d+,\d+,\d+)",text)
  if regex:
    price.append(regex[0])
  else:
    price.append(np.nan)

for i in soup.find_all("span",class_ = "_2JX5N"):
  text = i.text
  regex = re.findall("₹(\d+,\d+,\d+|\d+,\d+)",text)
  if regex:
    downpayment.append(regex[0])
  else:
    downpayment.append(np.nan)

# %% [markdown]
# ##### location

# %%
url = "https://www.cars24.com/buy-used-maruti-cars-Surat/"
req = requests.get(url)
soup = BeautifulSoup(req.text)

for i in soup.find_all("div",class_ ="_1Bq4a"):
  text = i.text

  regex = re.findall("Surat",text)
  print(regex)
# Out:
# ['Surat']

# %%
size8 = len(brand) - len(Location)
for j in range(0,size8):
  Location.append(regex[0])

# %% [markdown]
# ### pune

# %% [markdown]
# ##### maruti

# %%
url = "https://www.cars24.com/buy-used-maruti-cars-pune/"
req = requests.get(url)
soup = BeautifulSoup(req.text)

for i in soup.find_all("h3",class_="_2lmIw"):
  text = i.text
  regex1 = re.findall(("(\d+)\s"),text)
  regex2 = re.findall("Maruti",text)
  if regex1:
    model_year.append(regex1[0])
  else:
    model_year.append(np.nan)
  if regex2:
    brand.append(regex2[0])
  else:
    brand.append(np.nan)
  model.append(text[12:])

for i in soup.find_all("ul",class_="_1hOnS"):
  text = i.text
  regex = re.findall("Manual|Automatic",text)
  if regex:
    transmission.append(regex[0])
  else:
    transmission.append(np.nan)

for i in soup.find_all("ul",class_ = "_13yb6"):
  text = i.text
  regex = re.findall("\d+,\d+,\d+|\d+,\d+",text)
  regex2 = re.findall("km(\d+)",text)
  regex3 = re.findall("Petrol|Diesel|CNG|LPG",text)
  if regex:
    distance.append(regex[0])
  else:
    distance.append(np.nan)
  if regex2:
    ownership.append(regex2[0])
  else:
    ownership.append(np.nan)
  if regex3:
    fuel.append(regex3[0])
  else:
    fuel.append(np.nan)

for i in soup.find_all("div",class_ = "_18ToE"):
  text = i.text
  regex = re.findall("^₹(\d+,\d+,\d+)",text)
  if regex:
    price.append(regex[0])
  else:
    price.append(np.nan)

for i in soup.find_all("span",class_ = "_2JX5N"):
  text = i.text
  regex = re.findall("₹(\d+,\d+,\d+|\d+,\d+)",text)
  if regex:
    downpayment.append(regex[0])
  else:
    downpayment.append(np.nan)

# %% [markdown]
# ##### hyundai

# %%
url = "https://www.cars24.com/buy-used-hyundai-cars-pune/"
req = requests.get(url)
soup = BeautifulSoup(req.text)


for i in soup.find_all("h3",class_="_2lmIw"):
  text = i.text
  regex1 = re.findall(("(\d+)\s"),text)
  regex2 = re.findall("Hyundai",text)
  if regex1:
    model_year.append(regex1[0])
  else:
    model_year.append(np.nan)
  if regex2:
    brand.append(regex2[0])
  else:
    brand.append(np.nan)
  model.append(text[13:])

for i in soup.find_all("ul",class_="_1hOnS"):
  text = i.text
  regex = re.findall("Manual|Automatic",text)
  if regex:
    transmission.append(regex[0])
  else:
    transmission.append(np.nan)

for i in soup.find_all("ul",class_ = "_13yb6"):
  text = i.text
  regex = re.findall("\d+,\d+,\d+|\d+,\d+",text)
  regex2 = re.findall("km(\d+)",text)
  regex3 = re.findall("Petrol|Diesel|CNG|LPG",text)
  if regex:
    distance.append(regex[0])
  else:
    distance.append(np.nan)
  if regex2:
    ownership.append(regex2[0])
  else:
    ownership.append(np.nan)
  if regex3:
    fuel.append(regex3[0])
  else:
    fuel.append(np.nan)

for i in soup.find_all("div",class_ = "_18ToE"):
  text = i.text
  regex = re.findall("^₹(\d+,\d+,\d+)",text)
  if regex:
    price.append(regex[0])
  else:
    price.append(np.nan)

for i in soup.find_all("span",class_ = "_2JX5N"):
  text = i.text
  regex = re.findall("₹(\d+,\d+,\d+|\d+,\d+)",text)
  if regex:
    downpayment.append(regex[0])
  else:
    downpayment.append(np.nan)

# %% [markdown]
# ##### honda

# %%
url = "https://www.cars24.com/buy-used-honda-cars-pune/"
req = requests.get(url)
soup = BeautifulSoup(req.text)


for i in soup.find_all("h3",class_="_2lmIw"):
  text = i.text
  regex1 = re.findall(("(\d+)\s"),text)
  regex2 = re.findall("Honda",text)
  if regex1:
    model_year.append(regex1[0])
  else:
    model_year.append(np.nan)
  if regex2:
    brand.append(regex2[0])
  else:
    brand.append(np.nan)
  model.append(text[11:])

for i in soup.find_all("ul",class_="_1hOnS"):
  text = i.text
  regex = re.findall("Manual|Automatic",text)
  if regex:
    transmission.append(regex[0])
  else:
    transmission.append(np.nan)

for i in soup.find_all("ul",class_ = "_13yb6"):
  text = i.text
  regex = re.findall("\d+,\d+,\d+|\d+,\d+",text)
  regex2 = re.findall("km(\d+)",text)
  regex3 = re.findall("Petrol|Diesel|CNG|LPG",text)
  if regex:
    distance.append(regex[0])
  else:
    distance.append(np.nan)
  if regex2:
    ownership.append(regex2[0])
  else:
    ownership.append(np.nan)
  if regex3:
    fuel.append(regex3[0])
  else:
    fuel.append(np.nan)

for i in soup.find_all("div",class_ = "_18ToE"):
  text = i.text
  regex = re.findall("^₹(\d+,\d+,\d+)",text)
  if regex:
    price.append(regex[0])
  else:
    price.append(np.nan)

for i in soup.find_all("span",class_ = "_2JX5N"):
  text = i.text
  regex = re.findall("₹(\d+,\d+,\d+|\d+,\d+)",text)
  if regex:
    downpayment.append(regex[0])
  else:
    downpayment.append(np.nan)

# %% [markdown]
# ##### tata

# %%
url = "https://www.cars24.com/buy-used-tata-cars-pune/"
req = requests.get(url)
soup = BeautifulSoup(req.text)


for i in soup.find_all("h3",class_="_2lmIw"):
  text = i.text
  regex1 = re.findall(("(\d+)\s"),text)
  regex2 = re.findall("Tata",text)
  if regex1:
    model_year.append(regex1[0])
  else:
    model_year.append(np.nan)
  if regex2:
    brand.append(regex2[0])
  else:
    brand.append(np.nan)
  model.append(text[10:])

for i in soup.find_all("ul",class_="_1hOnS"):
  text = i.text
  regex = re.findall("Manual|Automatic",text)
  if regex:
    transmission.append(regex[0])
  else:
    transmission.append(np.nan)

for i in soup.find_all("ul",class_ = "_13yb6"):
  text = i.text
  regex = re.findall("\d+,\d+,\d+|\d+,\d+",text)
  regex2 = re.findall("km(\d+)",text)
  regex3 = re.findall("Petrol|Diesel|CNG|LPG",text)
  if regex:
    distance.append(regex[0])
  else:
    distance.append(np.nan)
  if regex2:
    ownership.append(regex2[0])
  else:
    ownership.append(np.nan)
  if regex3:
    fuel.append(regex3[0])
  else:
    fuel.append(np.nan)

for i in soup.find_all("div",class_ = "_18ToE"):
  text = i.text
  regex = re.findall("^₹(\d+,\d+,\d+)",text)
  if regex:
    price.append(regex[0])
  else:
    price.append(np.nan)

for i in soup.find_all("span",class_ = "_2JX5N"):
  text = i.text
  regex = re.findall("₹(\d+,\d+,\d+|\d+,\d+)",text)
  if regex:
    downpayment.append(regex[0])
  else:
    downpayment.append(np.nan)

# %% [markdown]
# ##### mahindra

# %%
url = "https://www.cars24.com/buy-used-mahindra-cars-pune/"
req = requests.get(url)
soup = BeautifulSoup(req.text)


for i in soup.find_all("h3",class_="_2lmIw"):
  text = i.text
  regex1 = re.findall(("(\d+)\s"),text)
  regex2 = re.findall("Mahindra",text)
  if regex1:
    model_year.append(regex1[0])
  else:
    model_year.append(np.nan)
  if regex2:
    brand.append(regex2[0])
  else:
    brand.append(np.nan)
  model.append(text[14:])

for i in soup.find_all("ul",class_="_1hOnS"):
  text = i.text
  regex = re.findall("Manual|Automatic",text)
  if regex:
    transmission.append(regex[0])
  else:
    transmission.append(np.nan)

for i in soup.find_all("ul",class_ = "_13yb6"):
  text = i.text
  regex = re.findall("\d+,\d+,\d+|\d+,\d+",text)
  regex2 = re.findall("km(\d+)",text)
  regex3 = re.findall("Petrol|Diesel|CNG|LPG",text)
  if regex:
    distance.append(regex[0])
  else:
    distance.append(np.nan)
  if regex2:
    ownership.append(regex2[0])
  else:
    ownership.append(np.nan)
  if regex3:
    fuel.append(regex3[0])
  else:
    fuel.append(np.nan)

for i in soup.find_all("div",class_ = "_18ToE"):
  text = i.text
  regex = re.findall("^₹(\d+,\d+,\d+)",text)
  if regex:
    price.append(regex[0])
  else:
    price.append(np.nan)

for i in soup.find_all("span",class_ = "_2JX5N"):
  text = i.text
  regex = re.findall("₹(\d+,\d+,\d+|\d+,\d+)",text)
  if regex:
    downpayment.append(regex[0])
  else:
    downpayment.append(np.nan)

# %% [markdown]
# ##### location

# %%
url = "https://www.cars24.com/buy-used-maruti-cars-pune/"
req = requests.get(url)
soup = BeautifulSoup(req.text)

for i in soup.find_all("div",class_ ="_1Bq4a"):
  text = i.text

  regex = re.findall("Pune",text)
  print(regex)
# Out:
# ['Pune']

# %%
size9 = len(brand) - len(Location)
for j in range(0,size9):
  Location.append(regex[0])

# %% [markdown]
# ## DATAFRAME GENERATION

# %%
dic = {"Brand":brand,"Model":model,"Model_year":model_year,"Location":Location,"Distance_travelled(in km)":distance,"Ownership":ownership,"Price(in Rs.)":price,"Transmission":transmission,"Fuel_type":fuel,"Downpayment(in Rs.)":downpayment}

# %%
df = pd.DataFrame(dic)

# %%
df
# Out:
#         Brand        Model Model_year   Location Distance_travelled(in km)  \
# 0      Maruti  New Wagon-R       2019  New Delhi                    48,404
# 1      Maruti  Wagon R 1.0       2010  New Delhi                    61,569
# 2      Maruti        Swift       2020  New Delhi                    44,817
# 3      Maruti        Swift       2018  New Delhi                    34,966
# 4      Maruti        Swift       2018  New Delhi                    64,216
# ..        ...          ...        ...        ...                       ...
# 838  Mahindra      XUV 3OO       2021       Pune                    19,034
# 839  Mahindra      XUV 3OO       2021       Pune                    79,714
# 840  Mahindra         Thar       2022       Pune                    12,956
# 841  Mahindra       XUV500       2015       Pune                    98,242
# 842  Mahindra   BOLERO NEO       2021       Pune                    28,449
#
# ...

# %%
df.to_csv("Used_Car_Data.csv",index=False)

# %%
pd.read_csv("Used_Car_Data.csv")
# Out:
#         Brand        Model  Model_year   Location Distance_travelled(in km)  \
# 0      Maruti  New Wagon-R        2019  New Delhi                    48,404
# 1      Maruti  Wagon R 1.0        2010  New Delhi                    61,569
# 2      Maruti        Swift        2020  New Delhi                    44,817
# 3      Maruti        Swift        2018  New Delhi                    34,966
# 4      Maruti        Swift        2018  New Delhi                    64,216
# ..        ...          ...         ...        ...                       ...
# 838  Mahindra      XUV 3OO        2021       Pune                    19,034
# 839  Mahindra      XUV 3OO        2021       Pune                    79,714
# 840  Mahindra         Thar        2022       Pune                    12,956
# 841  Mahindra       XUV500        2015       Pune                    98,242
# 842  Mahindra   BOLERO NEO        2021       Pune                    28,449
#
# ...

# %% [markdown]
# ## DATA CLEANING

# %% [markdown]
# ### REMOVING NULL VALUES

# %%
df = pd.read_csv(r"/content/drive/MyDrive/project/Used_Car_Data.csv")

# %%
df
# Out:
#         Brand        Model  Model_year   Location Distance_travelled(in km)  \
# 0      Maruti  New Wagon-R        2019  New Delhi                    48,404
# 1      Maruti  Wagon R 1.0        2010  New Delhi                    61,569
# 2      Maruti        Swift        2020  New Delhi                    44,817
# 3      Maruti        Swift        2018  New Delhi                    34,966
# 4      Maruti        Swift        2018  New Delhi                    64,216
# ..        ...          ...         ...        ...                       ...
# 838  Mahindra      XUV 3OO        2021       Pune                    19,034
# 839  Mahindra      XUV 3OO        2021       Pune                    79,714
# 840  Mahindra         Thar        2022       Pune                    12,956
# 841  Mahindra       XUV500        2015       Pune                    98,242
# 842  Mahindra   BOLERO NEO        2021       Pune                    28,449
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 843 entries, 0 to 842
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Brand                      843 non-null    object
#  1   Model                      843 non-null    object
#  2   Model_year                 843 non-null    int64
#  3   Location                   843 non-null    object
#  4   Distance_travelled(in km)  841 non-null    object
#  5   Ownership                  843 non-null    int64
#  6   Price(in Rs.)              843 non-null    object
#  7   Transmission               843 non-null    object
#  8   Fuel_type                  843 non-null    object
#  9   Downpayment(in Rs.)        843 non-null    object
# dtypes: int64(2), object(8)
# memory usage: 66.0+ KB

# %%
df.dropna(inplace=True)     # dropping rows having null values

# %% [markdown]
# ### TRANSFORMING DATA TYPE OF NECESSARY COLUMNS

# %%
df['Distance_travelled(in km)']=df['Distance_travelled(in km)'].str.replace(',','').astype(int)     # changing the data type of required columns

# %%
df['Downpayment(in Rs.)']=df['Downpayment(in Rs.)'].str.replace(',','').astype(int)     # changing the data type of required columns

# %%
df['Price(in Rs.)']=df['Price(in Rs.)'].str.replace(',','').astype(int)     # changing the data type of required columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 841 entries, 0 to 842
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Brand                      841 non-null    object
#  1   Model                      841 non-null    object
#  2   Model_year                 841 non-null    int64
#  3   Location                   841 non-null    object
#  4   Distance_travelled(in km)  841 non-null    int64
#  5   Ownership                  841 non-null    int64
#  6   Price(in Rs.)              841 non-null    int64
#  7   Transmission               841 non-null    object
#  8   Fuel_type                  841 non-null    object
#  9   Downpayment(in Rs.)        841 non-null    int64
# dtypes: int64(5), object(5)
# memory usage: 72.3+ KB

# %%
df
# Out:
#         Brand        Model  Model_year   Location  Distance_travelled(in km)  \
# 0      Maruti  New Wagon-R        2019  New Delhi                      48404
# 1      Maruti  Wagon R 1.0        2010  New Delhi                      61569
# 2      Maruti        Swift        2020  New Delhi                      44817
# 3      Maruti        Swift        2018  New Delhi                      34966
# 4      Maruti        Swift        2018  New Delhi                      64216
# ..        ...          ...         ...        ...                        ...
# 838  Mahindra      XUV 3OO        2021       Pune                      19034
# 839  Mahindra      XUV 3OO        2021       Pune                      79714
# 840  Mahindra         Thar        2022       Pune                      12956
# 841  Mahindra       XUV500        2015       Pune                      98242
# 842  Mahindra   BOLERO NEO        2021       Pune                      28449
#
# ...

# %%
df.to_csv("Used_Car_Data_modified.csv",index=False)

# %%
df = pd.read_csv("Used_Car_Data_modified.csv")

# %%
df
# Out:
#         Brand        Model  Model_year   Location  Distance_travelled(in km)  \
# 0      Maruti  New Wagon-R        2019  New Delhi                      48404
# 1      Maruti  Wagon R 1.0        2010  New Delhi                      61569
# 2      Maruti        Swift        2020  New Delhi                      44817
# 3      Maruti        Swift        2018  New Delhi                      34966
# 4      Maruti        Swift        2018  New Delhi                      64216
# ..        ...          ...         ...        ...                        ...
# 836  Mahindra      XUV 3OO        2021       Pune                      19034
# 837  Mahindra      XUV 3OO        2021       Pune                      79714
# 838  Mahindra         Thar        2022       Pune                      12956
# 839  Mahindra       XUV500        2015       Pune                      98242
# 840  Mahindra   BOLERO NEO        2021       Pune                      28449
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 841 entries, 0 to 840
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Brand                      841 non-null    object
#  1   Model                      841 non-null    object
#  2   Model_year                 841 non-null    int64
#  3   Location                   841 non-null    object
#  4   Distance_travelled(in km)  841 non-null    int64
#  5   Ownership                  841 non-null    int64
#  6   Price(in Rs.)              841 non-null    int64
#  7   Transmission               841 non-null    object
#  8   Fuel_type                  841 non-null    object
#  9   Downpayment(in Rs.)        841 non-null    int64
# dtypes: int64(5), object(5)
# memory usage: 65.8+ KB

# %%
df = pd.read_csv(r"/content/drive/MyDrive/project/Used_Car_Data_modified.csv")

# %%
df
# Out:
#         Brand        Model  Model_year   Location  Distance_travelled(in km)  \
# 0      Maruti  New Wagon-R        2019  New Delhi                      48404
# 1      Maruti  Wagon R 1.0        2010  New Delhi                      61569
# 2      Maruti        Swift        2020  New Delhi                      44817
# 3      Maruti        Swift        2018  New Delhi                      34966
# 4      Maruti        Swift        2018  New Delhi                      64216
# ..        ...          ...         ...        ...                        ...
# 836  Mahindra      XUV 3OO        2021       Pune                      19034
# 837  Mahindra      XUV 3OO        2021       Pune                      79714
# 838  Mahindra         Thar        2022       Pune                      12956
# 839  Mahindra       XUV500        2015       Pune                      98242
# 840  Mahindra   BOLERO NEO        2021       Pune                      28449
#
# ...

# %% [markdown]
# ### REMOVING OUTLIERS

# %%
plt.figure(figsize=(15,8))
sns.boxplot(data = df,y = "Brand",x = "Price(in Rs.)")     # outliers in price for each brand
plt.show()

# %%
df_trim = df.copy()

# %%
def iqr_trimming(df, cols, factor):

    drop_outliers = np.array([])

    for col in cols:

        q1 = df[col].quantile(0.25)
        q3 = df[col].quantile(0.75)

        iqr = q3 - q1

        upper_whisker = q3 + (factor*iqr)
        lower_whisker = q1 - (factor*iqr)

        s = df[col]

        indexes = s[(s > upper_whisker) | (s< lower_whisker)].index

        drop_outliers = np.append(drop_outliers, indexes)

    return drop_outliers

# %%
df.columns
# Out:
# Index(['Brand', 'Model', 'Model_year', 'Location', 'Distance_travelled(in km)',
#        'Ownership', 'Price(in Rs.)', 'Transmission', 'Fuel_type',
#        'Downpayment(in Rs.)'],
#       dtype='object')

# %%
features = ['Distance_travelled(in km)', 'Price(in Rs.)','Downpayment(in Rs.)']
features
# Out:
# ['Distance_travelled(in km)', 'Price(in Rs.)', 'Downpayment(in Rs.)']

# %%
dropped = np.unique(iqr_trimming(df_trim, features, 1.5))

# %%
df_trim.drop(dropped,inplace = True)

# %%
df_trim
# Out:
#         Brand        Model  Model_year   Location  Distance_travelled(in km)  \
# 0      Maruti  New Wagon-R        2019  New Delhi                      48404
# 1      Maruti  Wagon R 1.0        2010  New Delhi                      61569
# 2      Maruti        Swift        2020  New Delhi                      44817
# 3      Maruti        Swift        2018  New Delhi                      34966
# 4      Maruti        Swift        2018  New Delhi                      64216
# ..        ...          ...         ...        ...                        ...
# 836  Mahindra      XUV 3OO        2021       Pune                      19034
# 837  Mahindra      XUV 3OO        2021       Pune                      79714
# 838  Mahindra         Thar        2022       Pune                      12956
# 839  Mahindra       XUV500        2015       Pune                      98242
# 840  Mahindra   BOLERO NEO        2021       Pune                      28449
#
# ...

# %% [markdown]
# ### SAVING FINAL DATAFRAME

# %%
df_trim.to_csv('Final_DataFrame.csv',index = False)

# %%
df = pd.read_csv(r'/content/drive/MyDrive/project/Final_DataFrame.csv')     # Final Dataframe

# %%
df
# Out:
#         Brand        Model  Model_year   Location  Distance_travelled(in km)  \
# 0      Maruti  New Wagon-R        2019  New Delhi                      48404
# 1      Maruti  Wagon R 1.0        2010  New Delhi                      61569
# 2      Maruti        Swift        2020  New Delhi                      44817
# 3      Maruti        Swift        2018  New Delhi                      34966
# 4      Maruti        Swift        2018  New Delhi                      64216
# ..        ...          ...         ...        ...                        ...
# 797  Mahindra      XUV 3OO        2021       Pune                      19034
# 798  Mahindra      XUV 3OO        2021       Pune                      79714
# 799  Mahindra         Thar        2022       Pune                      12956
# 800  Mahindra       XUV500        2015       Pune                      98242
# 801  Mahindra   BOLERO NEO        2021       Pune                      28449
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 802 entries, 0 to 801
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Brand                      802 non-null    object
#  1   Model                      802 non-null    object
#  2   Model_year                 802 non-null    int64
#  3   Location                   802 non-null    object
#  4   Distance_travelled(in km)  802 non-null    int64
#  5   Ownership                  802 non-null    int64
#  6   Price(in Rs.)              802 non-null    int64
#  7   Transmission               802 non-null    object
#  8   Fuel_type                  802 non-null    object
#  9   Downpayment(in Rs.)        802 non-null    int64
# dtypes: int64(5), object(5)
# memory usage: 62.8+ KB

# %% [markdown]
# # EXPLANATORY DATA ANALYSIS

# %%
df['Model'].value_counts().plot(kind = 'bar',figsize=(20,5))
plt.title('Model Name')
plt.xlabel('Model')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.show()

# %% [markdown]
# * **Top 5 models listed on the website are:**
#
#   1. **Honda City**
#   2. **Tata Tiago**
#   3. **Hyundai Nexon**
#   4. **Honda Amaze**
#   5. **Tata XUV 300**
#
# * **From the top 5 listed cars 2 cars are from Honda, 2 cars are from Tata and 1 from Hyundai**.

# %%
plt.figure(figsize=(15, 10))
for i in range(0,len(df.Brand.unique())):
  plt.subplot(3, 2, i+1)
  df[df['Brand']==df.Brand.unique()[i]]['Model'].value_counts().plot(kind = 'bar')
  name  = df.Brand.unique()[i]
  plt.title(f'{name} Brand Model')
  plt.xlabel('Model')
  plt.ylabel('Count')
  plt.xticks(rotation=45, ha='right')

plt.tight_layout()
plt.show()

# %% [markdown]
# * **Most listed used car model from each company**
#
# 1.   **Swift from Maruti**
# 2.   **i10 from Hyundai**
# 3.   **City from Honda**
# 4.   **Tiago from Tata**
# 5.   **XUV 300 from Mahindra**
#
# * **Least listed used car model from each company**
#
# 1.   **Celerio X fro Maruti**
# 2.   **Tucson New from Hyundai**
# 3.   **Civic from Honda**
# 4.   **Zest from Tata**
# 5.   **Bolero Neo from Mahindra**

# %%
numerical_cols = df[['Distance_travelled(in km)','Price(in Rs.)','Downpayment(in Rs.)']]

# %%
numerical_cols.describe().round(2)
# Out:
#        Distance_travelled(in km)  Price(in Rs.)  Downpayment(in Rs.)
# count                     802.00         802.00               802.00
# mean                    57005.61      581432.38            116286.47
# std                     29983.61      271993.94             54398.79
# min                      1410.00      135000.00             27000.00
# 25%                     32635.25      382000.00             76400.00
# 50%                     55306.00      541500.00            108300.00
# 75%                     81252.00      743000.00            148600.00
# max                    134096.00     1369000.00            273800.00

# %%
plt.figure(figsize=(12, 8))
plt.subplot(3,3,1)
sns.histplot(df['Distance_travelled(in km)'])
plt.subplot(3,3,2)
plt.ticklabel_format(style='plain')
sns.kdeplot(df['Distance_travelled(in km)'])
plt.subplot(3,3,3)
sns.boxplot(y=df['Distance_travelled(in km)'])
plt.subplot(3,3,4)
sns.histplot(df['Price(in Rs.)'])
plt.subplot(3,3,5)
plt.ticklabel_format(style='plain')
sns.kdeplot(df['Price(in Rs.)'])
plt.subplot(3,3,6)
plt.ticklabel_format(style='plain')
sns.boxplot(y=df['Price(in Rs.)'])
plt.subplot(3,3,7)
sns.histplot(df['Downpayment(in Rs.)'])
plt.subplot(3,3,8)
plt.ticklabel_format(style='plain')
sns.kdeplot(df['Downpayment(in Rs.)'])
plt.subplot(3,3,9)
sns.boxplot(y=df['Downpayment(in Rs.)'])
plt.tight_layout()
plt.show()

# %%
numerical_cols.skew()
# Out:
# Distance_travelled(in km)    0.206035
# Price(in Rs.)                0.692572
# Downpayment(in Rs.)          0.692572
# dtype: float64

# %%
correlation_matrix = numerical_cols.corr()
plt.figure(figsize=(3, 3))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm',mask = np.triu(correlation_matrix))
plt.title('Correlation Matrix of Numerical Features')
plt.show()

# %% [markdown]
# * **The distance traveled by cars ranges from 1,400 km to 134,000 km, with an average of 57,000 km. 75% of the cars have been driven less than 80,000 km. Hence, sellers are mostly listing cars with lower mileage to attract buyers. The histogram and density plot show a slightly right-skewed distribution, indicating that very high-mileage cars are less frequently listed on the website.**
#
# * **The listed prices range from ₹1,35,000 to ₹13,70,000, with an average of ₹5,81,500. 75% of the cars are priced below ₹7,43,000. The histogram and density plot show a significantly right-skewed distribution, indicating that very high-priced cars are less frequently listed on the website.**
#
# * **The listed downpayment range from ₹27,000 to ₹2,73,800, with an average of ₹1,16,000. 75% of the cars have a downpayment below ₹1,49,000. The histogram and density plot show a significantly right-skewed distribution, indicating that cars with very high downpayments are less frequently listed on the website. Also downpayment correlates strongly with price (expected, as downpayment is a percentage of total price).**

# %%
df[df['Distance_travelled(in km)']>80000.00]['Brand'].value_counts()
# Out:
# Brand
# Honda       60
# Hyundai     53
# Maruti      46
# Mahindra    28
# Tata        18
# Name: count, dtype: int64

# %% [markdown]
# * **Honda, Hyundai, and Maruti make up the majority of cars in the top 25% of highest distance traveled. This suggests that sellers tend to list these brands after years of use or long-distance driving.**

# %%
df[df['Price(in Rs.)']>743000]['Brand'].value_counts()
# Out:
# Brand
# Mahindra    87
# Tata        52
# Hyundai     26
# Honda       22
# Maruti      14
# Name: count, dtype: int64

# %% [markdown]
# * **Mahindra and Tata comprise the majority of cars in the top 25% of highest-priced listings, suggesting that sellers tend to price these brands higher.**

# %%
pd.crosstab(columns = df['Brand'],index = df['Model_year']).plot(kind = 'line',figsize=(15,6))
plt.title('Brand vs Model Year')
plt.xlabel('Model Year')
plt.ylabel('Count')
plt.show()

# %%
df.groupby('Brand')['Distance_travelled(in km)'].mean().round(2).plot(kind = 'bar',figsize=(3,3))
plt.title('Brand vs Mean Distance Travelled')
plt.xlabel('Brand')
plt.ylabel('Distance Travelled(in km)')
plt.xticks(rotation=45, ha='right')
plt.show()

# %% [markdown]
# * **The line chart depicting the number of cars listed by each brand over time supports our previous finding on distance traveled. Older cars, primarily from Honda, Hyundai, and Maruti, are more commonly listed, whereas most newer cars come from Tata and Mahindra.**
# * **The bar graph further supports the findings of the line chart.**

# %%
df['Model_year'].value_counts().plot(kind = 'pie',autopct='%1.1f%%',textprops={'fontsize': 10})
plt.title('Model Year Distribution')
plt.ylabel('')
plt.show()

# %% [markdown]
# * **Nearly 62% of the models are from the years 2014 to 2019, indicating that consumers typically sell their cars after 4 to 9 years of use.**
# * **The highest number of models are from 2017, while the lowest are from 2023.**

# %%
ownership_data = df['Ownership'].value_counts()
plt.figure(figsize=(4,4))
plt.pie(ownership_data, labels=ownership_data.index, autopct='%1.1f%%', startangle=90)
centre_circle = plt.Circle((0, 0), 0.70, fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
plt.axis('equal')
plt.title('Ownership Distribution')
plt.show()

# %% [markdown]
# * **First-owner cars are the most frequently listed on the website.**

# %%
pd.crosstab(index = df['Brand'],columns = df['Ownership']).plot(kind = 'bar',figsize=(5,3))
plt.title('Brand vs Ownership')
plt.xlabel('Brand')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# * **First-owner cars are the most frequently listed on the website.**
# * **Honda, Hyundai, and Maruti have more second- and third-owner cars compared to Tata and Mahindra. This also justifies Older cars are primarily from Honda, Hyundai, and Maruti whereas most newer cars come from Tata and Mahindra.**

# %%
plt.figure(figsize=(6,3))
sns.barplot(y='Ownership', x='Distance_travelled(in km)', data=df,width=0.5,orient='h')
plt.title('Mean Distance Travelled vs. Ownership')
plt.ylabel('Ownership')
plt.xlabel('Distance Travelled (in km)')
plt.show()

# %%
plt.figure(figsize=(8, 4))
plt.ticklabel_format(style='plain')
sns.stripplot(y='Ownership', x='Price(in Rs.)', data=df, jitter=0.3, marker='o', alpha=0.5,orient = 'h')
sns.boxplot(y='Ownership', x='Price(in Rs.)', data=df, color='lightgray', width=0.3,orient = 'h')
plt.title('Ownership vs. Price')
plt.ylabel('Ownership')
plt.xlabel('Price (in Rs.)')
plt.show()

# %% [markdown]
# * **First-owner cars are priced approximately 15% to 20% higher than second-owner cars and around 40% to 50% higher than third-owner cars. This may be due to the higher distance traveled by cars with multiple owners. Very high priced second-owner and third-owner cars can be considered outliers.**

# %%
df['Transmission'].value_counts()
# Out:
# Transmission
# Manual       683
# Automatic    119
# Name: count, dtype: int64

# %%
df['Transmission'].value_counts().plot(kind = 'barh',figsize=(8,3))
plt.title('Transmission Distribution')
plt.ylabel('Transmission')
plt.xlabel('Count')
plt.show()

# %% [markdown]
# * **The number of manual transmission cars listed on the website is nearly six times that of automatic cars.**

# %%
df.groupby('Transmission')['Distance_travelled(in km)'].mean().round(2)
# Out:
# Transmission
# Automatic    50846.66
# Manual       58078.70
# Name: Distance_travelled(in km), dtype: float64

# %%
plt.figure(figsize=(8, 4))
sns.violinplot(data=df, y = 'Transmission', x='Distance_travelled(in km)',orient = 'h',hue = 'Transmission')
plt.title('Transmission vs. Distance Travelled')
plt.xlabel('Distance Travelled (in km)')
plt.ylabel('Transmission')
plt.show()

# %% [markdown]
# * **The distance traveled for manual and automatic cars is nearly the same, with manual cars having a mean distance traveled that is 8,000 to 10,000 km higher than automatic cars.**

# %%
df.groupby('Transmission')['Price(in Rs.)'].mean().round(2)
# Out:
# Transmission
# Automatic    766363.45
# Manual       549211.60
# Name: Price(in Rs.), dtype: float64

# %%
plt.figure(figsize=(8, 4))
plt.ticklabel_format(style='plain')
sns.stripplot(y='Transmission', x='Price(in Rs.)', data=df, jitter=0.3, marker='o', alpha=0.5,orient = 'h')
sns.boxplot(y='Transmission', x='Price(in Rs.)', data=df, color='lightgray', width=0.3,orient = 'h')
plt.title('Transmission vs. Price')
plt.ylabel('Transmission')
plt.xlabel('Price (in Rs.)')
plt.show()

# %% [markdown]
# * **The mean prices and distribution indicate that automatic cars are priced higher despite having a similar distance traveled. This may be due to higher initial purchase prices or other factors.**

# %%
plt.figure(figsize=(3,3))
df['Fuel_type'].value_counts().plot(kind = 'pie',autopct='%1.1f%%',textprops={'fontsize': 10})
plt.title('Fuel Type Distribution')
plt.ylabel('')
plt.show()

# %% [markdown]
# * **Petrol cars are the most frequently listed on the website, followed by diesel and CNG cars.**

# %%
pd.crosstab(index = df['Brand'],columns = df['Fuel_type']).plot(kind = 'barh',figsize=(10,3))
plt.title('Brand vs Fuel_type')
plt.xlabel('Brand')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# - **No CNG cars are listed from Mahindra.**
# - **Petrol cars are the most frequently listed on the website.**
# - **Mahindra is the only brand where diesel cars are listed more than petrol cars.**
# - **Maruti leads in the number of listed CNG cars.**

# %%
df.groupby('Fuel_type')['Distance_travelled(in km)'].mean().round(2).sort_values(ascending = False)
# Out:
# Fuel_type
# Diesel    68259.98
# CNG       64928.93
# Petrol    53266.56
# Name: Distance_travelled(in km), dtype: float64

# %% [markdown]
# * **Diesel and CNG cars have a mean distance traveled 28% and 21% higher, respectively, compared to petrol cars.**

# %%
df.groupby('Fuel_type')['Price(in Rs.)'].mean().round(2).sort_values(ascending = False)
# Out:
# Fuel_type
# Diesel    809305.15
# Petrol    524683.91
# CNG       492456.67
# Name: Price(in Rs.), dtype: float64

# %% [markdown]
# * **Diesel and petrol cars are approximately 64% and 6.5% more expensive than CNG cars, respectively.**

# %%
plt.figure(figsize=(20, 5))
plt.subplot(1, 2, 1)
sns.barplot(y='Fuel_type', x='Distance_travelled(in km)', data=df, orient='h',hue = 'Brand')
plt.title('Fuel Type vs. Distance Travelled')
plt.ylabel('Fuel Type')
plt.xlabel('Distance Travelled (in km)')
plt.subplot(1, 2, 2)
plt.ticklabel_format(style='plain')
sns.barplot(y='Fuel_type', x='Price(in Rs.)', data=df, orient='h',hue = 'Brand')
plt.title('Fuel Type vs. Price')
plt.ylabel('Fuel Type')
plt.xlabel('Price (in Rs.)')
plt.show()

# %% [markdown]
# - **Honda, Hyundai, and Maruti cars have covered more distance regardless of fuel type.**
# - **Similarly, Mahindra and Tata cars have consistently traveled less compared to other brands, regardless of fuel type.**
# * **Diesel cars are priced higher than their petrol and CNG counterparts across all brands.**
# * **Mahindra and Tata cars are consistently priced higher than the other three brands, regardless of fuel type.**

# %%
df.groupby(['Location'])['Price(in Rs.)'].mean().round(2).sort_values(ascending = False)
# Out:
# Location
# Chennai      672433.33
# Hyderabad    637421.98
# Bangalore    632335.75
# Ahmedabad    623229.44
# Pune         588810.99
# Mumbai       583907.22
# New Delhi    555606.29
# Kolkata      468880.43
# Surat        451086.08
# Name: Price(in Rs.), dtype: float64

# %% [markdown]
# * **Chennai has the highest mean prices, followed by Hyderabad, Bangalore, and Ahmedabad, all above ₹6 lakhs.**
# * **Pune, Mumbai, and New Delhi have mean prices above ₹5 lakhs.**
# * **Kolkata and Surat have the lowest prices, with Surat having the lowest mean price, both below ₹5 lakhs.**

# %%
plt.figure(figsize=(15, 6))
plt.ticklabel_format(style='plain')
sns.barplot(data=df, x='Location', y='Price(in Rs.)',hue = 'Brand',width=0.5)
plt.title('Location vs Price Distribution')
plt.xlabel('Location')
plt.ylabel('Price(in Rs.)')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# * **Mahindra cars are the most expensive, followed by Tata in almost all locations. *(In Chennai, Mahindra cars are the costliest, followed by Honda.)***
# * **Honda is the third most expensive brand in most locations, except *Chennai (where Tata is third)*, and *Ahmedabad & Mumbai (where Hyundai holds the third spot).***
# * **Hyundai and Maruti generally have the least expensive cars across most locations.*(In Mumbai and Ahmedabad, Honda and Maruti have the lowest prices.)***

# %% [markdown]
# # **OVERALL INSIGHT**

# %% [markdown]
# The exploratory analysis reveals a nuanced used car market where mileage, price, and ownership play key roles in shaping buyer and seller behaviors:
#
# - **Mileage & Price Distribution:**
#   - Most cars are listed with relatively low mileage (75% under 80,000 km) and priced below ₹7,43,000, indicating a preference for lower usage vehicles.
#   - Both price and downpayment distributions are significantly right-skewed, with only a few high-priced or high downpayment listings.
#
# - **Brand & Ownership Trends:**
#   - Brands like **Honda, Hyundai, and Maruti** dominate the higher mileage segment, suggesting they are often sold after prolonged use, while **Mahindra and Tata** appear predominantly among higher-priced and newer listings.
#   - First-owner cars are the most common, and they command a premium—priced 15-20% higher than second-owner and 40-50% higher than third-owner vehicles.
#
# - **Fuel & Transmission Characteristics:**
#   - **Petrol cars** are the most frequently listed, with diesel and CNG following; however, diesel cars tend to be pricier and, along with CNG cars, cover more distance than their petrol counterparts.
#   - Manual transmission cars significantly outnumber automatics (approximately 6:1), yet automatic cars are priced higher, likely reflecting higher initial purchase prices or additional features.
#
# - **Regional Variations:**
#   - Price levels vary notably by location: Chennai leads with the highest mean prices (above ₹6 lakhs), while cities like Kolkata and Surat offer more budget-friendly options (below ₹5 lakhs).

# %% [markdown]
# #**RECOMMENDATIONS**

# %% [markdown]
# ### **For Buyers:**

# %% [markdown]
# - **Mileage vs. Price:** Focus on first-owner, low-mileage vehicles if resale value and condition are priorities, even if these come at a premium.
# - **Transmission Choice:** While manual cars dominate, consider automatic vehicles if you value added convenience despite a higher price.
# - **Fuel Type Considerations:** Evaluate the long-term benefits of petrol vs. diesel vs. CNG. CNG cars might offer cost savings, but diesel vehicles may have higher mileage—ensure to check maintenance histories.
# - **Location Leverage:** Explore listings in regions like Kolkata and Surat for potentially lower prices, but balance this with local service and resale considerations.
# - **Brand & Ownership History:** Recognize that brands like Mahindra and Tata tend to be newer and pricier, whereas high-mileage options from Honda, Hyundai, and Maruti might offer value for budget-conscious buyers.

# %% [markdown]
# ### **For Sellers:**

# %% [markdown]
# - **Emphasize Low Mileage:** Listing cars with lower mileage is advantageous since buyers show a strong preference for less-used vehicles.
# - **Ownership Premium:** Highlight first-owner status to justify higher pricing, and be mindful of the premium differences between first, second, and third-owner vehicles.
# - **Brand Positioning:**
#   - For brands like Mahindra and Tata, emphasize the newer model years and premium features.
#   - For Honda, Hyundai, and Maruti, focus on reliability and extensive usage history as a testament to durability.
# - **Fuel and Transmission:** Consider the market dynamics—manual cars are abundant, so competitive pricing can help; if selling an automatic, underscore any added technological or comfort benefits.
# - **Regional Strategy:** Adjust pricing strategies based on location-specific market trends. For instance, premium pricing in Chennai can be justified, while competitive pricing might be necessary in markets like Surat or Kolkata.
#
# By tailoring strategies to these insights, buyers can make more informed decisions, and sellers can better position their vehicles in a competitive market.
